# %% [markdown]
# # Using Sparsify One-Shot for Sparsifying MiniLM for a Semantic Search Use-Case

# %% [markdown]
# In this notebook, we aim to explore the capabilities of the innovative Sparsify one-shot method for quantizing a dense [MiniLM](https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2) model, thereby simplifying the DevOps workflow. We will also walk you through the process of abstracting ONNX exportation and optimization by utilizing the [DeepSparse Optimum integration](https://github.com/neuralmagic/optimum-deepsparse). Finally, we will evaluate and compare the accuracy and latency of both the dense and quantized MiniLM models. To demonstrate their effectiveness, we'll employ the Weaviate vector database to efficiently index and search embeddings, underlining the preservation of MiniLM's semantic search functionalities despite the use of INT8 quantization and one-shot weight pruning.

# %% [markdown]
# ## Installation
#
# We'll install the `optimum-deepsparse` library for ONNX exporting, `sentence-transformers` for generating embeddings, the `evaluate` repo for validating accuracy on the stsb dataset, `sparsify` and the `weaviate` Python client.

# %%
# !pip install git+https://github.com/neuralmagic/optimum-deepsparse.git
# !pip install git+https://github.com/neuralmagic/sparsify.git
# !pip install sentence-transformers evaluate
# !pip install weaviate-client
# Out:
# Collecting git+https://github.com/neuralmagic/optimum-deepsparse.git
#   Cloning https://github.com/neuralmagic/optimum-deepsparse.git to /tmp/pip-req-build-p9eoz4nc
#   Running command git clone --filter=blob:none --quiet https://github.com/neuralmagic/optimum-deepsparse.git /tmp/pip-req-build-p9eoz4nc
#   Resolved https://github.com/neuralmagic/optimum-deepsparse.git to commit 974aa296fdcc2512b26b3e1ed9fbf9f63c85b7a3
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting deepsparse-nightly (from optimum-deepsparse==0.1.0.dev0)
#   Downloading deepsparse_nightly-1.6.0.20230825-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (44.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 MB 18.7 MB/s eta 0:00:00
# Collecting optimum[exporters]>=1.8.0 (from optimum-deepsparse==0.1.0.dev0)
#   Downloading optimum-1.12.0-py3-none-any.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.6/380.6 kB 40.8 MB/s eta 0:00:00
# Collecting diffusers (from optimum-deepsparse==0.1.0.dev0)
#   Downloading diffusers-0.20.1-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.7 MB/s eta 0:00:00
# Collecting coloredlogs (from optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (1.12)
# Collecting transformers[sentencepiece]>=4.26.0 (from optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0)
#   Downloading transformers-4.32.1-py3-none-any.whl (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 103.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.10/dist-packages (from optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (2.0.1+cu118)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (23.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (1.23.5)
# Collecting huggingface-hub>=0.8.0 (from optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.5 MB/s eta 0:00:00
# Collecting datasets (from optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0)
#   Downloading datasets-2.14.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.3/519.3 kB 48.9 MB/s eta 0:00:00
# Collecting onnx (from optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0)
#   Downloading onnx-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 90.3 MB/s eta 0:00:00
# Collecting onnxruntime (from optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0)
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 110.0 MB/s eta 0:00:00
# Collecting timm (from optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0)
#   Downloading timm-0.9.5-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 102.4 MB/s eta 0:00:00
# Collecting sparsezoo-nightly~=1.6.0 (from deepsparse-nightly->optimum-deepsparse==0.1.0.dev0)
#   Downloading sparsezoo_nightly-1.6.0.20230825-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.1/139.1 kB 20.1 MB/s eta 0:00:00
# Collecting pydantic<2.0.0,>=1.8.2 (from deepsparse-nightly->optimum-deepsparse==0.1.0.dev0)
#   Downloading pydantic-1.10.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 79.3 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from deepsparse-nightly->optimum-deepsparse==0.1.0.dev0) (2.31.0)
# Requirement already satisfied: tqdm>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from deepsparse-nightly->optimum-deepsparse==0.1.0.dev0) (4.66.1)
# Requirement already satisfied: protobuf>=3.12.2 in /usr/local/lib/python3.10/dist-packages (from deepsparse-nightly->optimum-deepsparse==0.1.0.dev0) (3.20.3)
# Requirement already satisfied: click!=8.0.0,>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from deepsparse-nightly->optimum-deepsparse==0.1.0.dev0) (8.1.7)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers->optimum-deepsparse==0.1.0.dev0) (6.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers->optimum-deepsparse==0.1.0.dev0) (3.12.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers->optimum-deepsparse==0.1.0.dev0) (2023.6.3)
# Collecting safetensors>=0.3.1 (from diffusers->optimum-deepsparse==0.1.0.dev0)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.0 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers->optimum-deepsparse==0.1.0.dev0) (9.4.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (2023.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.8.0->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->deepsparse-nightly->optimum-deepsparse==0.1.0.dev0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->deepsparse-nightly->optimum-deepsparse==0.1.0.dev0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->deepsparse-nightly->optimum-deepsparse==0.1.0.dev0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->deepsparse-nightly->optimum-deepsparse==0.1.0.dev0) (2023.7.22)
# Requirement already satisfied: pandas>1.3 in /usr/local/lib/python3.10/dist-packages (from sparsezoo-nightly~=1.6.0->deepsparse-nightly->optimum-deepsparse==0.1.0.dev0) (1.5.3)
# Collecting py-machineid>=0.3.0 (from sparsezoo-nightly~=1.6.0->deepsparse-nightly->optimum-deepsparse==0.1.0.dev0)
#   Downloading py_machineid-0.4.3-py3-none-any.whl (4.4 kB)
# Collecting geocoder>=1.38.0 (from sparsezoo-nightly~=1.6.0->deepsparse-nightly->optimum-deepsparse==0.1.0.dev0)
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.9->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.9->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (16.0.6)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers[sentencepiece]>=4.26.0->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 101.4 MB/s eta 0:00:00
# Collecting sentencepiece!=0.1.92,>=0.1.91 (from transformers[sentencepiece]>=4.26.0->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 83.4 MB/s eta 0:00:00
# Collecting humanfriendly>=9.1 (from coloredlogs->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.2 MB/s eta 0:00:00
# Collecting xxhash (from datasets->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0)
#   Downloading xxhash-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 23.3 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (3.8.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers->optimum-deepsparse==0.1.0.dev0) (3.16.2)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (23.5.26)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (1.3.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (0.15.2+cu118)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (1.3.1)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from geocoder>=1.38.0->sparsezoo-nightly~=1.6.0->deepsparse-nightly->optimum-deepsparse==0.1.0.dev0) (0.18.3)
# Collecting ratelim (from geocoder>=1.38.0->sparsezoo-nightly~=1.6.0->deepsparse-nightly->optimum-deepsparse==0.1.0.dev0)
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from geocoder>=1.38.0->sparsezoo-nightly~=1.6.0->deepsparse-nightly->optimum-deepsparse==0.1.0.dev0) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>1.3->sparsezoo-nightly~=1.6.0->deepsparse-nightly->optimum-deepsparse==0.1.0.dev0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>1.3->sparsezoo-nightly~=1.6.0->deepsparse-nightly->optimum-deepsparse==0.1.0.dev0) (2023.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9->optimum[exporters]>=1.8.0->optimum-deepsparse==0.1.0.dev0) (2.1.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ratelim->geocoder>=1.38.0->sparsezoo-nightly~=1.6.0->deepsparse-nightly->optimum-deepsparse==0.1.0.dev0) (4.4.2)
# Building wheels for collected packages: optimum-deepsparse
#   Building wheel for optimum-deepsparse (pyproject.toml) ... done
#   Created wheel for optimum-deepsparse: filename=optimum_deepsparse-0.1.0.dev0-py3-none-any.whl size=27363 sha256=78c33c95eddf7b681c953b62d10cb420a39cdcef23ecc4fa96acba2b2dc995fb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-82t0kjhj/wheels/81/43/b1/daa61ee0cdffc431f52e71c5074df187ace14e92155e7e42e2
# Successfully built optimum-deepsparse
# Installing collected packages: tokenizers, sentencepiece, safetensors, py-machineid, xxhash, ratelim, pydantic, onnx, humanfriendly, dill, multiprocess, huggingface-hub, geocoder, coloredlogs, transformers, sparsezoo-nightly, onnxruntime, diffusers, deepsparse-nightly, datasets, timm, optimum, optimum-deepsparse
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.2.1
#     Uninstalling pydantic-2.2.1:
#       Successfully uninstalled pydantic-2.2.1
# Successfully installed coloredlogs-15.0.1 datasets-2.14.4 deepsparse-nightly-1.6.0.20230825 diffusers-0.20.1 dill-0.3.7 geocoder-1.38.1 huggingface-hub-0.16.4 humanfriendly-10.0 multiprocess-0.70.15 onnx-1.14.1 onnxruntime-1.15.1 optimum-1.12.0 optimum-deepsparse-0.1.0.dev0 py-machineid-0.4.3 pydantic-1.10.12 ratelim-0.1.6 safetensors-0.3.3 sentencepiece-0.1.99 sparsezoo-nightly-1.6.0.20230825 timm-0.9.5 tokenizers-0.13.3 transformers-4.32.1 xxhash-3.3.0
# Collecting git+https://github.com/neuralmagic/sparsify.git
#   Cloning https://github.com/neuralmagic/sparsify.git to /tmp/pip-req-build-ek3qcifc
#   Running command git clone --filter=blob:none --quiet https://github.com/neuralmagic/sparsify.git /tmp/pip-req-build-ek3qcifc
#   Resolved https://github.com/neuralmagic/sparsify.git to commit 7d5b20dc8dfdbbbbd27958afa2b59e3ac850c9d8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pydantic<2.0.0,>=1.8.2 in /usr/local/lib/python3.10/dist-packages (from sparsify-nightly==1.6.0.20230828) (1.10.12)
# Requirement already satisfied: pyyaml>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from sparsify-nightly==1.6.0.20230828) (6.0.1)
# Collecting click~=8.0.0 (from sparsify-nightly==1.6.0.20230828)
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sparsify-nightly==1.6.0.20230828) (2.12.3)
# Requirement already satisfied: setuptools>=56.0.0 in /usr/local/lib/python3.10/dist-packages (from sparsify-nightly==1.6.0.20230828) (67.7.2)
# Collecting optuna>=3.0.2 (from sparsify-nightly==1.6.0.20230828)
#   Downloading optuna-3.3.0-py3-none-any.whl (404 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.2/404.2 kB 13.9 MB/s eta 0:00:00
# Collecting onnxruntime-gpu (from sparsify-nightly==1.6.0.20230828)
#   Downloading onnxruntime_gpu-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: sparsezoo-nightly~=1.6.0.202308 in /usr/local/lib/python3.10/dist-packages (from sparsify-nightly==1.6.0.20230828) (1.6.0.20230825)
# Requirement already satisfied: deepsparse-nightly~=1.6.0.202308 in /usr/local/lib/python3.10/dist-packages (from sparsify-nightly==1.6.0.20230828) (1.6.0.20230825)
# Collecting sparseml-nightly[torchvision,yolov5]~=1.6.0.202308 (from sparsify-nightly==1.6.0.20230828)
#   Downloading sparseml_nightly-1.6.0.20230825-py3-none-any.whl (973 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.5/973.5 kB 76.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.10/dist-packages (from deepsparse-nightly~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (1.23.5)
# Requirement already satisfied: onnx<1.15.0,>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from deepsparse-nightly~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (1.14.1)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from deepsparse-nightly~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (2.31.0)
# Requirement already satisfied: tqdm>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from deepsparse-nightly~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (4.66.1)
# Requirement already satisfied: protobuf>=3.12.2 in /usr/local/lib/python3.10/dist-packages (from deepsparse-nightly~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (3.20.3)
# Collecting alembic>=1.5.0 (from optuna>=3.0.2->sparsify-nightly==1.6.0.20230828)
#   Downloading alembic-1.11.3-py3-none-any.whl (225 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.4/225.4 kB 25.3 MB/s eta 0:00:00
# Collecting cmaes>=0.10.0 (from optuna>=3.0.2->sparsify-nightly==1.6.0.20230828)
#   Downloading cmaes-0.10.0-py3-none-any.whl (29 kB)
# Collecting colorlog (from optuna>=3.0.2->sparsify-nightly==1.6.0.20230828)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=3.0.2->sparsify-nightly==1.6.0.20230828) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=3.0.2->sparsify-nightly==1.6.0.20230828) (2.0.20)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.0.0,>=1.8.2->sparsify-nightly==1.6.0.20230828) (4.7.1)
# Collecting setuptools>=56.0.0 (from sparsify-nightly==1.6.0.20230828)
#   Downloading setuptools-59.5.0-py3-none-any.whl (952 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.4/952.4 kB 68.4 MB/s eta 0:00:00
# Collecting jupyter>=1.0.0 (from sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (7.7.1)
# Requirement already satisfied: progressbar2>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (4.2.0)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (3.7.1)
# Collecting merge-args>=0.1.0 (from sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading merge_args-0.1.5-py2.py3-none-any.whl (6.0 kB)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.10/dist-packages (from sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (1.5.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (5.9.5)
# Requirement already satisfied: scikit-image>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.19.3)
# Requirement already satisfied: scikit-learn>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (1.2.2)
# Collecting toposort>=1.0 (from sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading toposort-1.10-py3-none-any.whl (8.5 kB)
# Collecting GPUtil>=1.4.0 (from sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (1.10.1)
# Collecting torch<=2.0,>=1.7.0 (from sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading torch-2.0.0-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.6 MB/s eta 0:00:00
# Collecting gputils (from sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading gputils-1.0.6-py3-none-any.whl (3.8 kB)
# Collecting torchvision<=0.15.1,>=0.3.0 (from sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading torchvision-0.15.1-cp310-cp310-manylinux1_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 79.6 MB/s eta 0:00:00
# Collecting opencv-python<=4.6.0.66 (from sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 11.0 MB/s eta 0:00:00
# Collecting nm-yolov5-nightly~=1.6.0 (from sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading nm_yolov5_nightly-1.6.0.20230825-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 75.9 MB/s eta 0:00:00
# Requirement already satisfied: py-machineid>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from sparsezoo-nightly~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.4.3)
# Requirement already satisfied: geocoder>=1.38.0 in /usr/local/lib/python3.10/dist-packages (from sparsezoo-nightly~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (1.38.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.0.0->sparsify-nightly==1.6.0.20230828) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.0.0->sparsify-nightly==1.6.0.20230828) (1.57.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.0.0->sparsify-nightly==1.6.0.20230828) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.0.0->sparsify-nightly==1.6.0.20230828) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.0.0->sparsify-nightly==1.6.0.20230828) (3.4.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.0.0->sparsify-nightly==1.6.0.20230828) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.0.0->sparsify-nightly==1.6.0.20230828) (2.3.7)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.0.0->sparsify-nightly==1.6.0.20230828) (0.41.2)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime-gpu->sparsify-nightly==1.6.0.20230828) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime-gpu->sparsify-nightly==1.6.0.20230828) (23.5.26)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime-gpu->sparsify-nightly==1.6.0.20230828) (1.12)
# Collecting Mako (from alembic>=1.5.0->optuna>=3.0.2->sparsify-nightly==1.6.0.20230828)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from geocoder>=1.38.0->sparsezoo-nightly~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.18.3)
# Requirement already satisfied: ratelim in /usr/local/lib/python3.10/dist-packages (from geocoder>=1.38.0->sparsezoo-nightly~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.1.6)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from geocoder>=1.38.0->sparsezoo-nightly~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.0.0->sparsify-nightly==1.6.0.20230828) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.0.0->sparsify-nightly==1.6.0.20230828) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.0.0->sparsify-nightly==1.6.0.20230828) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.0.0->sparsify-nightly==1.6.0.20230828) (1.3.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (3.6.5)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (3.0.8)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (6.5.5)
# Collecting qtconsole (from jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading qtconsole-5.4.3-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (6.5.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (2.8.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from nm-yolov5-nightly~=1.6.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.12.2)
# Collecting thop>=0.1.1 (from nm-yolov5-nightly~=1.6.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (2023.3)
# Requirement already satisfied: python-utils>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from progressbar2>=3.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (3.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->deepsparse-nightly~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->deepsparse-nightly~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->deepsparse-nightly~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->deepsparse-nightly~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (2023.7.22)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.15.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (3.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.15.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (2.31.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.15.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (2023.8.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.15.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (1.4.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.2->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.2->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (3.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna>=3.0.2->sparsify-nightly==1.6.0.20230828) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch<=2.0,>=1.7.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (3.12.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<=2.0,>=1.7.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (3.1.2)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch<=2.0,>=1.7.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 74.4 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch<=2.0,>=1.7.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 53.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch<=2.0,>=1.7.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 104.2 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch<=2.0,>=1.7.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.8 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch<=2.0,>=1.7.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 2.1 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch<=2.0,>=1.7.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 7.1 MB/s eta 0:00:00
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch<=2.0,>=1.7.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 11.5 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch<=2.0,>=1.7.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 9.0 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch<=2.0,>=1.7.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 4.5 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu11==2.14.3 (from torch<=2.0,>=1.7.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 6.6 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch<=2.0,>=1.7.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch<=2.0,>=1.7.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch<=2.0,>=1.7.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch<=2.0,>=1.7.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.0.0->sparsify-nightly==1.6.0.20230828) (2.1.3)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime-gpu->sparsify-nightly==1.6.0.20230828) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime-gpu->sparsify-nightly==1.6.0.20230828) (1.3.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (6.3.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets>=7.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading jedi-0.19.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 81.1 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (4.8.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.0.0->sparsify-nightly==1.6.0.20230828) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.0.0->sparsify-nightly==1.6.0.20230828) (3.2.2)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (5.3.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (5.9.2)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (1.5.7)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (1.0.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (1.2.1)
# Collecting qtpy>=2.0.1 (from qtconsole->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828)
#   Downloading QtPy-2.3.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (3.10.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.2.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (4.19.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.2.6)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (0.5.1)
# ...
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (1.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter>=1.0.0->sparseml-nightly[torchvision,yolov5]~=1.6.0.202308->sparsify-nightly==1.6.0.20230828) (2.21)
# Building wheels for collected packages: sparsify-nightly, GPUtil
#   Building wheel for sparsify-nightly (pyproject.toml) ... done
#   Created wheel for sparsify-nightly: filename=sparsify_nightly-1.6.0.20230828-py3-none-any.whl size=102424 sha256=cf2b93b53a77fd59c5f1d79acb0778a923d9fb0247f2c51d9b2faa2577e041c4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-m0pw0tv1/wheels/26/57/60/0622d5d8649a00eb10db75e5eac730d5e5b58b17b774f22b46
#   Building wheel for GPUtil (setup.py) ... done
#   Created wheel for GPUtil: filename=GPUtil-1.4.0-py3-none-any.whl size=7392 sha256=54bd299565366adf0d13d20c0cf5141f20a2454e0f0785114d820ab51e2ea997
#   Stored in directory: /root/.cache/pip/wheels/a9/8a/bd/81082387151853ab8b6b3ef33426e98f5cbfebc3c397a9d4d0
# Successfully built sparsify-nightly GPUtil
# Installing collected packages: toposort, merge-args, GPUtil, setuptools, qtpy, opencv-python, nvidia-nccl-cu11, nvidia-cufft-cu11, nvidia-cuda-nvrtc-cu11, Mako, jedi, colorlog, cmaes, click, onnxruntime-gpu, nvidia-nvtx-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, alembic, optuna, nvidia-cusolver-cu11, nvidia-cudnn-cu11, gputils, qtconsole, jupyter, sparseml-nightly, torch, torchvision, thop, nm-yolov5-nightly, sparsify-nightly
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.8.0.76
#     Uninstalling opencv-python-4.8.0.76:
#       Successfully uninstalled opencv-python-4.8.0.76
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
#     Uninstalling click-8.1.7:
#       Successfully uninstalled click-8.1.7
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.2+cu118
#     Uninstalling torchvision-0.15.2+cu118:
#       Successfully uninstalled torchvision-0.15.2+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# arviz 0.15.1 requires setuptools>=60.0.0, but you have setuptools 59.5.0 which is incompatible.
# cvxpy 1.3.2 requires setuptools>65.5.1, but you have setuptools 59.5.0 which is incompatible.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 2.0.0 which is incompatible.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 2.0.0 which is incompatible.
# torchtext 0.15.2 requires torch==2.0.1, but you have torch 2.0.0 which is incompatible.
# Successfully installed GPUtil-1.4.0 Mako-1.2.4 alembic-1.11.3 click-8.0.4 cmaes-0.10.0 colorlog-6.7.0 gputils-1.0.6 jedi-0.19.0 jupyter-1.0.0 merge-args-0.1.5 nm-yolov5-nightly-1.6.0.20230825 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 onnxruntime-gpu-1.15.1 opencv-python-4.6.0.66 optuna-3.3.0 qtconsole-5.4.3 qtpy-2.3.1 setuptools-59.5.0 sparseml-nightly-1.6.0.20230825 sparsify-nightly-1.6.0.20230828 thop-0.1.1.post2209072238 toposort-1.10 torch-2.0.0 torchvision-0.15.1
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.32.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.0.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.15.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.16.4)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.14.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.31.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.3.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.15)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (23.1)
# Collecting responses<0.19 (from evaluate)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (9.0.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.8.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2023.7.22)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence-transformers) (59.5.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence-transformers) (0.41.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.6.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.3.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.0.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers) (9.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125937 sha256=fbbf809b2470b9d2d5daec8558973b9fb7d7a6a2f7116a85bad52c2a8b28ab45
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: responses, evaluate, sentence-transformers
# Successfully installed evaluate-0.4.0 responses-0.18.0 sentence-transformers-2.2.2
# Collecting weaviate-client
#   Downloading weaviate_client-3.23.1-py3-none-any.whl (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: requests<=2.31.0,>=2.28.0 in /usr/local/lib/python3.10/dist-packages (from weaviate-client) (2.31.0)
# Collecting validators<=0.21.0,>=0.18.2 (from weaviate-client)
#   Downloading validators-0.21.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.59.0 in /usr/local/lib/python3.10/dist-packages (from weaviate-client) (4.66.1)
# Collecting authlib>=1.1.0 (from weaviate-client)
#   Downloading Authlib-1.2.1-py2.py3-none-any.whl (215 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.3/215.3 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=3.2 in /usr/local/lib/python3.10/dist-packages (from authlib>=1.1.0->weaviate-client) (41.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<=2.31.0,>=2.28.0->weaviate-client) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<=2.31.0,>=2.28.0->weaviate-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<=2.31.0,>=2.28.0->weaviate-client) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<=2.31.0,>=2.28.0->weaviate-client) (2023.7.22)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.2->authlib>=1.1.0->weaviate-client) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.2->authlib>=1.1.0->weaviate-client) (2.21)
# Installing collected packages: validators, authlib, weaviate-client
# Successfully installed authlib-1.2.1 validators-0.21.0 weaviate-client-3.23.1

# %% [markdown]
# ## Convert PyTorch Weights to ONNX

# %%
from optimum.deepsparse import DeepSparseModelForFeatureExtraction
from transformers.onnx.utils import get_preprocessor
from pathlib import Path

model_id="sentence-transformers/all-MiniLM-L6-v2"

# load model and convert to onnx
model = DeepSparseModelForFeatureExtraction.from_pretrained(model_id, export=True)
tokenizer = get_preprocessor(model_id)

# save onnx checkpoint and tokenizer
onnx_path = Path("dense_onnx")
model.save_pretrained(onnx_path)
tokenizer.save_pretrained(onnx_path)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Framework not specified. Using pt to export to ONNX.
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Using framework PyTorch: 2.0.0+cu117
# Overriding 1 configuration item(s)
# 	- use_cache -> False
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# ('dense_onnx/tokenizer_config.json',
#  'dense_onnx/special_tokens_map.json',
#  'dense_onnx/vocab.txt',
#  'dense_onnx/added_tokens.json',
#  'dense_onnx/tokenizer.json')

# %% [markdown]
# ## Data Prep Prior to Using Sparsify One-Shot
# Sparsify's One-Shot is a post-training sparsification method that utilizes sampled data (~1,000 samples is satisfactory) from a calibration dataset resulting in no further training time and much faster sparsification times compared with Training-Aware Experiments.
#
# The samples need to be stored in the `.npz` format, which is a file format based on the NumPy library. In the BERT model architecture, Sparsify one-shot requires the `input_ids`, `attention_mask` and `token_type_ids` of each data sample from your dataset to be stored as a dictionary prior to `.npz` storage. For more information, refer to the Sparsify [guide](https://github.com/neuralmagic/sparsify/blob/main/docs/datasets-guide.md#npz).
#
#  For our example, we'll use the popular semantic textual similarity benchmark (`stsb`) dataset for calibration. Now, let's extract 1,000 samples from the train split and convert them to `.npz`:

# %%
import os
import numpy as np
from datasets import load_dataset
from sentence_transformers import SentenceTransformer, InputExample

# Load the dataset
dataset = load_dataset("glue", "stsb", split="train")

# Adjusted to get the first 1000 examples
n_examples = 1000

# Create the "data" directory if it doesn't exist
if not os.path.exists('data'):
    os.makedirs('data')

# Load the Sentence Transformers model
model_name = "sentence-transformers/all-MiniLM-L6-v2"
model = SentenceTransformer(model_name)

train_examples = []
for i in range(n_examples):
    example = dataset[i]
    train_examples.append(InputExample(texts=[example['sentence1'], example['sentence2']]))

# Extract texts from InputExample instances
texts = [example.texts for example in train_examples]

# Generate embeddings for the extracted texts
embeddings = model.encode(texts, convert_to_tensor=True)
embeddings_cpu = embeddings.cpu().numpy()

for i in range(n_examples):
    example = dataset[i]

    # Create a dictionary to store the data
    npz_data = {
        'input_ids': embeddings_cpu[i],  # Store embeddings for this example
        'attention_mask': np.ones_like(embeddings_cpu[i]),  # Attention mask for embeddings
        'token_type_ids': np.zeros_like(embeddings_cpu[i])  # Token type IDs for embeddings
    }

    # Save the dictionary as an npz file
    npz_file_path = f'data/input_{i:04d}.npz'
    np.savez(npz_file_path, **npz_data)

print(f'Saved {n_examples} npz files to data/')
# Out:
# Downloading builder script:   0%|          | 0.00/28.8k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/28.7k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/27.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/803k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/5749 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1500 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1379 [00:00<?, ? examples/s]
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Saved 1000 npz files to data/

# %% [markdown]
# ## Login to Sparsify
#
# Prior to gaining access to the sparsify API, sign up for a free account [here](https://account.neuralmagic.com/signup). Then on your landing page, copy your personal API key and paste into the following command:

# %%
# !sparsify.login EJMfcp88Wpp7efA99WjAfSAFH6jhwfG9
# Out:
# INFO:sparsify.login:Logging into sparsify...
# INFO:sparsify.utils.helpers:Successfully authenticated with Neural Magic Account API key
# INFO:sparsify.login:Installing sparsifyml version 1.6 from neuralmagic pypi server
# Looking in indexes: https://nm:****@pypi.neuralmagic.com
# Collecting sparsifyml-nightly~=1.6
#   Downloading https://pypi.neuralmagic.com/packages/sparsifyml_nightly-1.6.0.20230828-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (847 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 847.1/847.1 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: sparsifyml-nightly
# Successfully installed sparsifyml-nightly-1.6.0.20230828
# INFO:sparsify.login:Logged in successfully, sparsify setup is complete.

# %% [markdown]
# ## Run One-Shot with Sparsify
#
# Running One-Shot requires a simple CLI command pointing to the model directory `./dense_onnx` (we previously created when exporting to ONNX) and the data directory `/data` which stores our 1,000 NPZ files. In addition, we use an optimization level of `0.5` (default). This argument controls how much sparsification is applied to the model (ranging from 0.1 to 0.9), with higher values resulting in faster and more compressed models with only a marginal drop in accuracy. For further inquiry, refer to the [one-shot guide](https://github.com/neuralmagic/sparsify/blob/main/docs/one-shot-experiment-guide.md).

# %%
# !sparsify.run one-shot --use-case nlp-text-classification --model ./dense_onnx/model.onnx --data ./data --optim-level 0.5
# Out:
# 2023-08-28 13:51:58.339187: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO:sparsify.utils.helpers:Successfully authenticated with Neural Magic Account API key
# INFO:sparsify.login:sparsifyml version 1.6 is already installed, skipping installation from neuralmagic pypi server
# WARNING:sparsify.check_environment.gpu_device:Checking for GPU...
# WARNING:sparsify.check_environment.gpu_device:GPU check completed successfully
# WARNING:sparsify.check_environment.ort_health:Checking onnxruntime-gpu environment health...
# 2023-08-28 13:52:00 deepsparse.utils.onnx INFO     Generating input 'X', type = float32, shape = [1, 3, 32, 32]
# INFO:deepsparse.utils.onnx:Generating input 'X', type = float32, shape = [1, 3, 32, 32]
# WARNING:sparsify.check_environment.ort_health:onnxruntime-gpu environment check completed successfully
# INFO:sparsifyml.one_shot.sparsification.obcq.fast_obcq_modifier:Folded 0 Conv-BatchNormalization blocks
# INFO:sparsifyml.one_shot.sparsification.obcq.base_obcq_modifier:FastOBCQModifier: starting compression on layers: ['/encoder/layer.0/attention/self/query/MatMul', '/encoder/layer.0/attention/self/value/MatMul', '/encoder/layer.0/attention/output/dense/MatMul', '/encoder/layer.0/intermediate/dense/MatMul', '/encoder/layer.0/output/dense/MatMul', '/encoder/layer.1/attention/self/key/MatMul', '/encoder/layer.1/attention/self/query/MatMul', '/encoder/layer.1/attention/self/value/MatMul', '/encoder/layer.1/attention/output/dense/MatMul', '/encoder/layer.1/intermediate/dense/MatMul', '/encoder/layer.1/output/dense/MatMul', '/encoder/layer.2/attention/self/key/MatMul', '/encoder/layer.2/attention/self/query/MatMul', '/encoder/layer.2/attention/self/value/MatMul', '/encoder/layer.2/attention/output/dense/MatMul', '/encoder/layer.2/intermediate/dense/MatMul', '/encoder/layer.2/output/dense/MatMul', '/encoder/layer.3/attention/self/key/MatMul', '/encoder/layer.3/attention/self/query/MatMul', '/encoder/layer.3/attention/self/value/MatMul', '/encoder/layer.3/attention/output/dense/MatMul', '/encoder/layer.3/intermediate/dense/MatMul', '/encoder/layer.3/output/dense/MatMul', '/encoder/layer.4/attention/self/key/MatMul', '/encoder/layer.4/attention/self/query/MatMul', '/encoder/layer.4/attention/self/value/MatMul', '/encoder/layer.4/attention/output/dense/MatMul', '/encoder/layer.4/intermediate/dense/MatMul', '/encoder/layer.4/output/dense/MatMul', '/encoder/layer.5/attention/self/key/MatMul', '/encoder/layer.5/attention/self/query/MatMul', '/encoder/layer.5/attention/self/value/MatMul', '/encoder/layer.5/attention/output/dense/MatMul', '/encoder/layer.5/intermediate/dense/MatMul']
# Calibration: 1001it [01:44,  9.57it/s]
# INFO:sparsifyml.one_shot.sparsification.obcq.base_obcq_modifier:saving H estimates to experiments/20230828-135207/OBCQ/H_estimates
# Compressing /encoder/layer.0/attention/self/query/MatMul:   0% 0/24 [00:00<?, ?it/s]WARNING:/usr/local/lib/python3.10/dist-packages/sparsifyml/one_shot/sparsification/obcq/utils/compression.py:H inversion failed with original dampening fraction of 0.001. It eventually succeeded with dampening fraction of 0.01
#
# Compressing /encoder/layer.0/attention/self/value/MatMul:   0% 0/24 [00:00<?, ?it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:   4% 1/24 [00:00<00:20,  1.14it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:   8% 2/24 [00:01<00:20,  1.08it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  17% 4/24 [00:03<00:19,  1.03it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  21% 5/24 [00:04<00:18,  1.02it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  25% 6/24 [00:05<00:18,  1.00s/it]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  29% 7/24 [00:06<00:17,  1.00s/it]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  33% 8/24 [00:07<00:15,  1.03it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  38% 9/24 [00:08<00:13,  1.10it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  42% 10/24 [00:09<00:12,  1.17it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  46% 11/24 [00:10<00:10,  1.21it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  50% 12/24 [00:10<00:09,  1.23it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  54% 13/24 [00:11<00:08,  1.24it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  58% 14/24 [00:12<00:07,  1.28it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  62% 15/24 [00:13<00:06,  1.30it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  67% 16/24 [00:13<00:06,  1.30it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  71% 17/24 [00:14<00:05,  1.31it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  75% 18/24 [00:15<00:04,  1.31it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  79% 19/24 [00:16<00:03,  1.33it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  83% 20/24 [00:16<00:03,  1.32it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  88% 21/24 [00:17<00:02,  1.32it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  92% 22/24 [00:18<00:01,  1.29it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul:  96% 23/24 [00:19<00:00,  1.27it/s]
# Compressing /encoder/layer.0/attention/self/query/MatMul: 100% 24/24 [00:20<00:00,  1.19it/s]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:   0% 0/24 [00:00<?, ?it/s]
# Compressing /encoder/layer.0/attention/self/value/MatMul: 100% 24/24 [00:20<00:00,  1.18it/s]
#
# Compressing /encoder/layer.0/attention/output/dense/MatMul:   4% 1/24 [00:00<00:22,  1.00it/s]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:   8% 2/24 [00:02<00:22,  1.01s/it]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  12% 3/24 [00:03<00:24,  1.15s/it]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  17% 4/24 [00:05<00:30,  1.53s/it]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  21% 5/24 [00:06<00:26,  1.39s/it]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  25% 6/24 [00:07<00:21,  1.20s/it]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  29% 7/24 [00:08<00:17,  1.06s/it]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  33% 8/24 [00:08<00:15,  1.04it/s]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  38% 9/24 [00:09<00:13,  1.12it/s]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  42% 10/24 [00:10<00:11,  1.17it/s]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  46% 11/24 [00:11<00:10,  1.21it/s]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  50% 12/24 [00:11<00:09,  1.24it/s]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  54% 13/24 [00:12<00:08,  1.26it/s]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  58% 14/24 [00:13<00:07,  1.28it/s]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  62% 15/24 [00:14<00:07,  1.28it/s]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  67% 16/24 [00:15<00:06,  1.28it/s]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  71% 17/24 [00:15<00:05,  1.28it/s]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  75% 18/24 [00:16<00:04,  1.30it/s]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  79% 19/24 [00:17<00:03,  1.28it/s]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  83% 20/24 [00:18<00:03,  1.25it/s]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  88% 21/24 [00:19<00:02,  1.22it/s]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  92% 22/24 [00:20<00:01,  1.16it/s]
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  96% 23/24 [00:21<00:00,  1.11it/s]
# Compressing /encoder/layer.0/attention/output/dense/MatMul: 100% 24/24 [00:22<00:00,  1.09it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:   0% 0/96 [00:00<?, ?it/s]
# Compressing /encoder/layer.0/intermediate/dense/MatMul: 100% 24/24 [00:21<00:00,  1.09it/s]
#
# Compressing /encoder/layer.0/output/dense/MatMul:   1% 1/96 [00:01<01:35,  1.01s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:   2% 2/96 [00:01<01:33,  1.00it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:   3% 3/96 [00:02<01:31,  1.02it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:   4% 4/96 [00:03<01:28,  1.04it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:   5% 5/96 [00:04<01:21,  1.12it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:   6% 6/96 [00:05<01:16,  1.18it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:   7% 7/96 [00:06<01:12,  1.22it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:   8% 8/96 [00:06<01:11,  1.24it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:   9% 9/96 [00:07<01:16,  1.14it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  10% 10/96 [00:09<01:21,  1.06it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  11% 11/96 [00:10<01:20,  1.06it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  12% 12/96 [00:11<01:21,  1.03it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  14% 13/96 [00:11<01:16,  1.08it/s]
# Compressing /encoder/layer.1/attention/self/key/MatMul:  54% 13/24 [00:11<00:10,  1.08it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  15% 14/96 [00:12<01:15,  1.08it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  17% 16/96 [00:14<01:19,  1.00it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  18% 17/96 [00:15<01:20,  1.02s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  19% 18/96 [00:17<01:23,  1.06s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  20% 19/96 [00:18<01:24,  1.10s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  21% 20/96 [00:19<01:25,  1.12s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  22% 21/96 [00:20<01:24,  1.13s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  23% 22/96 [00:21<01:25,  1.16s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  24% 23/96 [00:23<01:29,  1.23s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  25% 24/96 [00:24<01:28,  1.22s/it]
# Compressing /encoder/layer.1/attention/self/key/MatMul: 100% 24/24 [00:24<00:00,  1.02s/it]
#
# Compressing /encoder/layer.0/output/dense/MatMul:  26% 25/96 [00:25<01:21,  1.15s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  27% 26/96 [00:26<01:12,  1.04s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  28% 27/96 [00:26<01:05,  1.05it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  30% 29/96 [00:28<01:01,  1.09it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  31% 30/96 [00:30<01:08,  1.04s/it]
# Compressing /encoder/layer.1/attention/self/query/MatMul:  21% 5/24 [00:05<00:21,  1.13s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  33% 32/96 [00:32<01:03,  1.01it/s]
# Compressing /encoder/layer.1/attention/self/query/MatMul:  29% 7/24 [00:07<00:17,  1.04s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  34% 33/96 [00:32<01:01,  1.03it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  36% 35/96 [00:34<00:56,  1.09it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  38% 36/96 [00:35<00:56,  1.06it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  39% 37/96 [00:37<01:05,  1.11s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  40% 38/96 [00:38<01:13,  1.27s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  41% 39/96 [00:40<01:11,  1.25s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  42% 40/96 [00:41<01:05,  1.17s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  43% 41/96 [00:42<01:01,  1.11s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  44% 42/96 [00:43<00:58,  1.08s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  45% 43/96 [00:43<00:55,  1.05s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  46% 44/96 [00:44<00:53,  1.02s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  47% 45/96 [00:45<00:48,  1.06it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  48% 46/96 [00:46<00:44,  1.13it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  49% 47/96 [00:47<00:41,  1.18it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  50% 48/96 [00:47<00:39,  1.21it/s]
# Compressing /encoder/layer.1/attention/self/query/MatMul:  96% 23/24 [00:23<00:00,  1.24it/s]
# Compressing /encoder/layer.1/attention/self/query/MatMul: 100% 24/24 [00:24<00:00,  1.00s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  51% 49/96 [00:48<00:37,  1.24it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  52% 50/96 [00:49<00:36,  1.26it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  53% 51/96 [00:50<00:35,  1.28it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  54% 52/96 [00:51<00:34,  1.28it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  55% 53/96 [00:51<00:33,  1.30it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  56% 54/96 [00:52<00:32,  1.31it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  57% 55/96 [00:53<00:31,  1.31it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  58% 56/96 [00:54<00:30,  1.30it/s]
# Compressing /encoder/layer.1/attention/self/value/MatMul:  29% 7/24 [00:05<00:13,  1.31it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  59% 57/96 [00:54<00:30,  1.28it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  60% 58/96 [00:55<00:30,  1.24it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  61% 59/96 [00:56<00:29,  1.25it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  62% 60/96 [00:57<00:30,  1.19it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  64% 61/96 [00:58<00:30,  1.13it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  65% 62/96 [00:59<00:30,  1.10it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  66% 63/96 [01:00<00:30,  1.07it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  67% 64/96 [01:01<00:30,  1.05it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  69% 66/96 [01:03<00:29,  1.03it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  70% 67/96 [01:04<00:26,  1.09it/s]
# Compressing /encoder/layer.1/attention/self/value/MatMul:  75% 18/24 [00:15<00:05,  1.08it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  71% 68/96 [01:04<00:24,  1.13it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  73% 70/96 [01:06<00:21,  1.22it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  74% 71/96 [01:07<00:19,  1.25it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  75% 72/96 [01:08<00:18,  1.27it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  76% 73/96 [01:08<00:18,  1.27it/s]
# Compressing /encoder/layer.1/attention/self/value/MatMul: 100% 24/24 [00:20<00:00,  1.20it/s]
#
# Compressing /encoder/layer.0/output/dense/MatMul:  77% 74/96 [01:09<00:17,  1.27it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  78% 75/96 [01:10<00:16,  1.27it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  79% 76/96 [01:11<00:16,  1.22it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  80% 77/96 [01:12<00:15,  1.23it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  81% 78/96 [01:12<00:15,  1.20it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  82% 79/96 [01:13<00:14,  1.14it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  83% 80/96 [01:14<00:14,  1.08it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  84% 81/96 [01:16<00:15,  1.01s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  85% 82/96 [01:17<00:15,  1.09s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  86% 83/96 [01:18<00:14,  1.11s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  88% 84/96 [01:19<00:14,  1.19s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  89% 85/96 [01:21<00:13,  1.20s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  90% 86/96 [01:22<00:12,  1.25s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  91% 87/96 [01:23<00:11,  1.26s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  92% 88/96 [01:24<00:09,  1.21s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  93% 89/96 [01:25<00:07,  1.09s/it]
# Compressing /encoder/layer.0/output/dense/MatMul:  94% 90/96 [01:26<00:05,  1.01it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  95% 91/96 [01:27<00:04,  1.08it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  96% 92/96 [01:28<00:03,  1.14it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  97% 93/96 [01:28<00:02,  1.21it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  98% 94/96 [01:29<00:01,  1.23it/s]
# Compressing /encoder/layer.0/output/dense/MatMul:  99% 95/96 [01:30<00:00,  1.25it/s]
# Compressing /encoder/layer.0/output/dense/MatMul: 100% 96/96 [01:31<00:00,  1.05it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:   0% 0/24 [00:00<?, ?it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:   4% 1/24 [00:00<00:17,  1.33it/s]
# Compressing /encoder/layer.1/attention/output/dense/MatMul: 100% 24/24 [00:23<00:00,  1.03it/s]
#
# Compressing /encoder/layer.1/intermediate/dense/MatMul:   8% 2/24 [00:01<00:16,  1.31it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  12% 3/24 [00:02<00:16,  1.31it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  17% 4/24 [00:03<00:15,  1.29it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  21% 5/24 [00:03<00:14,  1.29it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  25% 6/24 [00:04<00:14,  1.27it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  29% 7/24 [00:05<00:13,  1.24it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  33% 8/24 [00:06<00:13,  1.21it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  38% 9/24 [00:07<00:13,  1.12it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  42% 10/24 [00:08<00:13,  1.08it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  46% 11/24 [00:09<00:12,  1.05it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  50% 12/24 [00:10<00:11,  1.04it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  54% 13/24 [00:11<00:10,  1.03it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  58% 14/24 [00:12<00:09,  1.03it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  62% 15/24 [00:13<00:08,  1.07it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  67% 16/24 [00:13<00:07,  1.14it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  71% 17/24 [00:14<00:05,  1.18it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  75% 18/24 [00:15<00:04,  1.21it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  79% 19/24 [00:16<00:04,  1.24it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  83% 20/24 [00:17<00:03,  1.26it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  88% 21/24 [00:17<00:02,  1.27it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  92% 22/24 [00:18<00:01,  1.29it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  96% 23/24 [00:19<00:00,  1.29it/s]
# Compressing /encoder/layer.1/intermediate/dense/MatMul: 100% 24/24 [00:20<00:00,  1.19it/s]
# Compressing /encoder/layer.2/attention/self/key/MatMul:   0% 0/24 [00:00<?, ?it/s]
# Compressing /encoder/layer.2/attention/self/key/MatMul:   4% 1/24 [00:00<00:17,  1.34it/s]
# Compressing /encoder/layer.2/attention/self/key/MatMul:   8% 2/24 [00:01<00:16,  1.33it/s]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  12% 3/24 [00:02<00:15,  1.32it/s]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  17% 4/24 [00:03<00:15,  1.27it/s]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  21% 5/24 [00:03<00:15,  1.24it/s]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  25% 6/24 [00:05<00:16,  1.08it/s]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  29% 7/24 [00:06<00:18,  1.11s/it]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  33% 8/24 [00:07<00:17,  1.10s/it]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  38% 9/24 [00:08<00:16,  1.07s/it]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  42% 10/24 [00:09<00:14,  1.05s/it]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  46% 11/24 [00:10<00:13,  1.04s/it]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  50% 12/24 [00:11<00:12,  1.03s/it]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  54% 13/24 [00:12<00:10,  1.02it/s]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  58% 14/24 [00:13<00:09,  1.09it/s]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  62% 15/24 [00:14<00:07,  1.15it/s]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  67% 16/24 [00:14<00:06,  1.19it/s]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  71% 17/24 [00:15<00:05,  1.23it/s]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  75% 18/24 [00:16<00:04,  1.25it/s]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  79% 19/24 [00:17<00:03,  1.27it/s]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  83% 20/24 [00:17<00:03,  1.27it/s]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  88% 21/24 [00:18<00:02,  1.19it/s]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  92% 22/24 [00:19<00:01,  1.09it/s]
# Compressing /encoder/layer.2/attention/self/key/MatMul:  96% 23/24 [00:21<00:00,  1.05it/s]
# Compressing /encoder/layer.2/attention/self/key/MatMul: 100% 24/24 [00:22<00:00,  1.08it/s]
# Compressing /encoder/layer.2/attention/self/query/MatMul:   0% 0/24 [00:00<?, ?it/s]
# Compressing /encoder/layer.2/attention/self/query/MatMul:   4% 1/24 [00:01<00:30,  1.31s/it]
# Compressing /encoder/layer.2/attention/self/query/MatMul:   8% 2/24 [00:02<00:31,  1.42s/it]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  12% 3/24 [00:04<00:31,  1.51s/it]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  17% 4/24 [00:06<00:30,  1.54s/it]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  21% 5/24 [00:07<00:28,  1.51s/it]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  25% 6/24 [00:08<00:26,  1.47s/it]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  29% 7/24 [00:10<00:24,  1.47s/it]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  33% 8/24 [00:11<00:23,  1.49s/it]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  38% 9/24 [00:13<00:20,  1.38s/it]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  42% 10/24 [00:14<00:17,  1.27s/it]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  46% 11/24 [00:15<00:15,  1.20s/it]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  50% 12/24 [00:16<00:13,  1.15s/it]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  54% 13/24 [00:16<00:11,  1.06s/it]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  58% 14/24 [00:17<00:10,  1.04s/it]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  62% 15/24 [00:18<00:08,  1.01it/s]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  67% 16/24 [00:19<00:07,  1.02it/s]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  71% 17/24 [00:20<00:07,  1.03s/it]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  75% 18/24 [00:22<00:06,  1.05s/it]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  79% 19/24 [00:22<00:04,  1.02it/s]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  83% 20/24 [00:23<00:03,  1.09it/s]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  88% 21/24 [00:24<00:02,  1.09it/s]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  92% 22/24 [00:25<00:01,  1.07it/s]
# Compressing /encoder/layer.2/attention/self/query/MatMul:  96% 23/24 [00:26<00:00,  1.05it/s]
# Compressing /encoder/layer.2/attention/self/query/MatMul: 100% 24/24 [00:27<00:00,  1.15s/it]
# Compressing /encoder/layer.2/attention/self/value/MatMul:   0% 0/24 [00:00<?, ?it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:   4% 1/24 [00:00<00:22,  1.01it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:   8% 2/24 [00:01<00:21,  1.01it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  12% 3/24 [00:02<00:20,  1.01it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  17% 4/24 [00:03<00:18,  1.10it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  21% 5/24 [00:04<00:16,  1.18it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  25% 6/24 [00:05<00:14,  1.22it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  29% 7/24 [00:05<00:13,  1.27it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  33% 8/24 [00:06<00:12,  1.28it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  38% 9/24 [00:07<00:11,  1.29it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  42% 10/24 [00:08<00:10,  1.30it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  46% 11/24 [00:09<00:09,  1.31it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  50% 12/24 [00:09<00:09,  1.30it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  54% 13/24 [00:10<00:08,  1.30it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  58% 14/24 [00:11<00:07,  1.30it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  62% 15/24 [00:12<00:06,  1.31it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  67% 16/24 [00:12<00:06,  1.32it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  71% 17/24 [00:13<00:05,  1.24it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  75% 18/24 [00:14<00:04,  1.22it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  79% 19/24 [00:15<00:04,  1.20it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  83% 20/24 [00:16<00:03,  1.13it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  88% 21/24 [00:17<00:02,  1.08it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  92% 22/24 [00:18<00:01,  1.06it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul:  96% 23/24 [00:19<00:00,  1.04it/s]
# Compressing /encoder/layer.2/attention/self/value/MatMul: 100% 24/24 [00:20<00:00,  1.17it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:   0% 0/24 [00:00<?, ?it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:   4% 1/24 [00:00<00:22,  1.03it/s]
# Compressing /encoder/layer.1/output/dense/MatMul: 100% 96/96 [01:30<00:00,  1.06it/s]
#
# Compressing /encoder/layer.2/attention/output/dense/MatMul:   8% 2/24 [00:01<00:20,  1.09it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  12% 3/24 [00:02<00:17,  1.18it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  17% 4/24 [00:03<00:16,  1.20it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  21% 5/24 [00:04<00:15,  1.24it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  25% 6/24 [00:04<00:14,  1.26it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  29% 7/24 [00:05<00:13,  1.27it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  33% 8/24 [00:06<00:12,  1.29it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  38% 9/24 [00:07<00:11,  1.29it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  42% 10/24 [00:08<00:11,  1.17it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  46% 11/24 [00:09<00:10,  1.19it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  50% 12/24 [00:09<00:09,  1.23it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  54% 13/24 [00:10<00:08,  1.25it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  58% 14/24 [00:11<00:07,  1.26it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  62% 15/24 [00:12<00:07,  1.23it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  67% 16/24 [00:13<00:06,  1.25it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  71% 17/24 [00:13<00:05,  1.20it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  75% 18/24 [00:14<00:05,  1.12it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  79% 19/24 [00:15<00:04,  1.09it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  83% 20/24 [00:16<00:03,  1.06it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  88% 21/24 [00:17<00:02,  1.04it/s]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  92% 22/24 [00:19<00:02,  1.02s/it]
# Compressing /encoder/layer.2/attention/output/dense/MatMul:  96% 23/24 [00:20<00:01,  1.11s/it]
# Compressing /encoder/layer.2/attention/output/dense/MatMul: 100% 24/24 [00:21<00:00,  1.11it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:   0% 0/96 [00:00<?, ?it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:   1% 1/96 [00:01<01:53,  1.19s/it]
# Compressing /encoder/layer.2/intermediate/dense/MatMul: 100% 24/24 [00:21<00:00,  1.10it/s]
#
# Compressing /encoder/layer.2/output/dense/MatMul:   2% 2/96 [00:02<01:48,  1.16s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:   3% 3/96 [00:03<01:41,  1.09s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:   4% 4/96 [00:04<01:36,  1.04s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:   5% 5/96 [00:05<01:31,  1.00s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:   6% 6/96 [00:06<01:32,  1.03s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:   7% 7/96 [00:07<01:28,  1.00it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:   8% 8/96 [00:08<01:24,  1.05it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:   9% 9/96 [00:09<01:24,  1.03it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  10% 10/96 [00:10<01:24,  1.02it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  11% 11/96 [00:11<01:27,  1.03s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  12% 12/96 [00:13<01:44,  1.24s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  14% 13/96 [00:14<01:54,  1.38s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  15% 14/96 [00:16<02:01,  1.48s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  16% 15/96 [00:18<02:11,  1.62s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  17% 16/96 [00:20<02:10,  1.63s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  18% 17/96 [00:21<02:15,  1.71s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  19% 18/96 [00:22<01:56,  1.50s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  20% 19/96 [00:23<01:42,  1.33s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  21% 20/96 [00:24<01:34,  1.25s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  22% 21/96 [00:26<01:32,  1.23s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  23% 22/96 [00:27<01:31,  1.24s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  24% 23/96 [00:28<01:31,  1.25s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  25% 24/96 [00:29<01:21,  1.13s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  26% 25/96 [00:30<01:15,  1.06s/it]
# Compressing /encoder/layer.3/attention/self/key/MatMul: 100% 24/24 [00:29<00:00,  1.21s/it]
#
# Compressing /encoder/layer.2/output/dense/MatMul:  27% 26/96 [00:31<01:12,  1.04s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  28% 27/96 [00:32<01:08,  1.01it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  29% 28/96 [00:33<01:11,  1.04s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  30% 29/96 [00:34<01:11,  1.07s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  31% 30/96 [00:35<01:11,  1.09s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  32% 31/96 [00:36<01:15,  1.16s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  33% 32/96 [00:38<01:17,  1.21s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  34% 33/96 [00:39<01:12,  1.15s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  35% 34/96 [00:40<01:08,  1.10s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  36% 35/96 [00:41<01:05,  1.08s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  38% 36/96 [00:42<01:02,  1.05s/it]
# Compressing /encoder/layer.2/output/dense/MatMul:  39% 37/96 [00:43<00:56,  1.04it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  40% 38/96 [00:43<00:52,  1.10it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  41% 39/96 [00:44<00:49,  1.15it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  42% 40/96 [00:45<00:46,  1.20it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  43% 41/96 [00:46<00:45,  1.21it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  44% 42/96 [00:46<00:43,  1.24it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  45% 43/96 [00:47<00:41,  1.27it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  46% 44/96 [00:48<00:40,  1.28it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  47% 45/96 [00:49<00:39,  1.30it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  48% 46/96 [00:49<00:38,  1.31it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  49% 47/96 [00:50<00:37,  1.31it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  50% 48/96 [00:51<00:36,  1.31it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  51% 49/96 [00:52<00:41,  1.14it/s]
# Compressing /encoder/layer.3/attention/self/query/MatMul: 100% 24/24 [00:22<00:00,  1.07it/s]
#
# Compressing /encoder/layer.2/output/dense/MatMul:  52% 50/96 [00:53<00:42,  1.08it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  53% 51/96 [00:54<00:40,  1.10it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  54% 52/96 [00:55<00:41,  1.07it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  55% 53/96 [00:56<00:41,  1.03it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  56% 54/96 [00:57<00:40,  1.03it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  57% 55/96 [00:58<00:40,  1.02it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  58% 56/96 [00:59<00:39,  1.01it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  59% 57/96 [01:00<00:38,  1.01it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  60% 58/96 [01:01<00:36,  1.03it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  61% 59/96 [01:02<00:33,  1.10it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  62% 60/96 [01:03<00:31,  1.15it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  64% 61/96 [01:03<00:29,  1.20it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  65% 62/96 [01:04<00:27,  1.22it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  66% 63/96 [01:05<00:26,  1.26it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  67% 64/96 [01:06<00:25,  1.27it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  68% 65/96 [01:06<00:24,  1.28it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  69% 66/96 [01:07<00:22,  1.31it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  70% 67/96 [01:08<00:22,  1.32it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  71% 68/96 [01:09<00:21,  1.31it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  72% 69/96 [01:09<00:20,  1.31it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  73% 70/96 [01:10<00:19,  1.31it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  74% 71/96 [01:11<00:19,  1.31it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  75% 72/96 [01:12<00:18,  1.27it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  76% 73/96 [01:13<00:18,  1.26it/s]
# Compressing /encoder/layer.3/attention/self/value/MatMul: 100% 24/24 [00:19<00:00,  1.20it/s]
#
# Compressing /encoder/layer.2/output/dense/MatMul:  77% 74/96 [01:14<00:18,  1.17it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  78% 75/96 [01:15<00:19,  1.08it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  79% 76/96 [01:16<00:18,  1.08it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  80% 77/96 [01:17<00:17,  1.06it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  81% 78/96 [01:18<00:17,  1.05it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  82% 79/96 [01:19<00:16,  1.04it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  83% 80/96 [01:19<00:15,  1.05it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  84% 81/96 [01:20<00:13,  1.13it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  85% 82/96 [01:21<00:11,  1.18it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  86% 83/96 [01:22<00:10,  1.23it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  88% 84/96 [01:22<00:09,  1.27it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  89% 85/96 [01:23<00:08,  1.28it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  90% 86/96 [01:24<00:07,  1.28it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  91% 87/96 [01:25<00:06,  1.30it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  92% 88/96 [01:25<00:06,  1.32it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  93% 89/96 [01:26<00:05,  1.32it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  94% 90/96 [01:27<00:04,  1.31it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  95% 91/96 [01:28<00:03,  1.33it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  96% 92/96 [01:28<00:03,  1.32it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  97% 93/96 [01:29<00:02,  1.32it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  98% 94/96 [01:30<00:01,  1.29it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:  99% 95/96 [01:31<00:00,  1.27it/s]
# Compressing /encoder/layer.2/output/dense/MatMul: 100% 96/96 [01:32<00:00,  1.04it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:   0% 0/24 [00:00<?, ?it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:   4% 1/24 [00:01<00:23,  1.01s/it]
# Compressing /encoder/layer.3/attention/output/dense/MatMul: 100% 24/24 [00:20<00:00,  1.19it/s]
#
# Compressing /encoder/layer.3/intermediate/dense/MatMul:   8% 2/24 [00:02<00:22,  1.01s/it]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  12% 3/24 [00:02<00:20,  1.01it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  17% 4/24 [00:03<00:19,  1.01it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  21% 5/24 [00:04<00:18,  1.02it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  25% 6/24 [00:05<00:17,  1.03it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  29% 7/24 [00:06<00:15,  1.07it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  33% 8/24 [00:07<00:13,  1.15it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  38% 9/24 [00:08<00:12,  1.20it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  42% 10/24 [00:09<00:11,  1.21it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  46% 11/24 [00:09<00:10,  1.24it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  50% 12/24 [00:10<00:09,  1.26it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  54% 13/24 [00:11<00:08,  1.26it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  58% 14/24 [00:12<00:07,  1.27it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  62% 15/24 [00:12<00:07,  1.26it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  67% 16/24 [00:13<00:06,  1.27it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  71% 17/24 [00:14<00:05,  1.29it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  75% 18/24 [00:15<00:04,  1.29it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  79% 19/24 [00:15<00:03,  1.31it/s]
# Compressing /encoder/layer.3/output/dense/MatMul:  19% 18/96 [00:14<00:59,  1.32it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  83% 20/24 [00:16<00:03,  1.28it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  88% 21/24 [00:17<00:02,  1.28it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  92% 22/24 [00:18<00:01,  1.24it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  96% 23/24 [00:19<00:00,  1.15it/s]
# Compressing /encoder/layer.3/intermediate/dense/MatMul: 100% 24/24 [00:20<00:00,  1.17it/s]
# Compressing /encoder/layer.4/attention/self/key/MatMul:   0% 0/24 [00:00<?, ?it/s]
# Compressing /encoder/layer.4/attention/self/key/MatMul:   4% 1/24 [00:00<00:22,  1.03it/s]
# Compressing /encoder/layer.4/attention/self/key/MatMul:   8% 2/24 [00:01<00:21,  1.02it/s]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  12% 3/24 [00:02<00:20,  1.02it/s]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  17% 4/24 [00:03<00:19,  1.02it/s]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  21% 5/24 [00:04<00:17,  1.08it/s]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  25% 6/24 [00:05<00:15,  1.15it/s]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  29% 7/24 [00:06<00:14,  1.21it/s]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  33% 8/24 [00:06<00:12,  1.26it/s]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  38% 9/24 [00:07<00:11,  1.29it/s]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  46% 11/24 [00:09<00:09,  1.32it/s]
# Compressing /encoder/layer.3/output/dense/MatMul:  35% 34/96 [00:28<00:48,  1.29it/s]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  50% 12/24 [00:09<00:09,  1.31it/s]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  54% 13/24 [00:10<00:08,  1.30it/s]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  58% 14/24 [00:11<00:07,  1.29it/s]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  62% 15/24 [00:12<00:07,  1.24it/s]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  67% 16/24 [00:13<00:06,  1.21it/s]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  71% 17/24 [00:14<00:06,  1.17it/s]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  75% 18/24 [00:15<00:05,  1.02it/s]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  79% 19/24 [00:16<00:05,  1.01s/it]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  83% 20/24 [00:17<00:04,  1.09s/it]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  88% 21/24 [00:19<00:03,  1.20s/it]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  92% 22/24 [00:20<00:02,  1.20s/it]
# Compressing /encoder/layer.4/attention/self/key/MatMul:  96% 23/24 [00:22<00:01,  1.38s/it]
# Compressing /encoder/layer.4/attention/self/key/MatMul: 100% 24/24 [00:24<00:00,  1.01s/it]
# Compressing /encoder/layer.4/attention/self/query/MatMul:   0% 0/24 [00:00<?, ?it/s]
# Compressing /encoder/layer.4/attention/self/query/MatMul:   4% 1/24 [00:01<00:29,  1.30s/it]
# Compressing /encoder/layer.4/attention/self/query/MatMul:   8% 2/24 [00:02<00:24,  1.13s/it]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  12% 3/24 [00:03<00:22,  1.06s/it]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  17% 4/24 [00:04<00:20,  1.03s/it]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  21% 5/24 [00:05<00:18,  1.04it/s]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  25% 6/24 [00:06<00:17,  1.02it/s]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  29% 7/24 [00:06<00:15,  1.07it/s]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  33% 8/24 [00:07<00:14,  1.14it/s]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  38% 9/24 [00:08<00:13,  1.10it/s]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  42% 10/24 [00:09<00:12,  1.12it/s]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  46% 11/24 [00:10<00:11,  1.14it/s]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  50% 12/24 [00:11<00:10,  1.18it/s]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  54% 13/24 [00:12<00:09,  1.14it/s]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  58% 14/24 [00:13<00:10,  1.00s/it]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  62% 15/24 [00:15<00:11,  1.24s/it]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  67% 16/24 [00:16<00:09,  1.17s/it]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  71% 17/24 [00:17<00:07,  1.12s/it]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  75% 18/24 [00:18<00:06,  1.07s/it]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  79% 19/24 [00:19<00:05,  1.05s/it]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  83% 20/24 [00:20<00:04,  1.03s/it]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  88% 21/24 [00:21<00:03,  1.00s/it]
# Compressing /encoder/layer.4/attention/self/query/MatMul:  92% 22/24 [00:21<00:01,  1.08it/s]
# Compressing /encoder/layer.4/attention/self/query/MatMul: 100% 24/24 [00:23<00:00,  1.03it/s]
#
# Compressing /encoder/layer.4/attention/self/value/MatMul:   0% 0/24 [00:00<?, ?it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:   4% 1/24 [00:00<00:17,  1.30it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  12% 3/24 [00:02<00:16,  1.30it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  17% 4/24 [00:03<00:15,  1.33it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  21% 5/24 [00:03<00:14,  1.33it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  25% 6/24 [00:04<00:13,  1.33it/s]
# Compressing /encoder/layer.3/output/dense/MatMul:  80% 77/96 [01:11<00:14,  1.30it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  29% 7/24 [00:05<00:12,  1.32it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  38% 9/24 [00:06<00:11,  1.35it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  42% 10/24 [00:07<00:10,  1.34it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  46% 11/24 [00:08<00:09,  1.32it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  50% 12/24 [00:09<00:09,  1.30it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  54% 13/24 [00:09<00:08,  1.29it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  58% 14/24 [00:10<00:08,  1.19it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  62% 15/24 [00:11<00:07,  1.13it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  67% 16/24 [00:12<00:07,  1.10it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  71% 17/24 [00:13<00:06,  1.08it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  75% 18/24 [00:14<00:05,  1.06it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  79% 19/24 [00:15<00:04,  1.06it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  83% 20/24 [00:16<00:03,  1.07it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  88% 21/24 [00:17<00:02,  1.14it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  92% 22/24 [00:18<00:01,  1.18it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul:  96% 23/24 [00:18<00:00,  1.22it/s]
# Compressing /encoder/layer.4/attention/self/value/MatMul: 100% 24/24 [00:19<00:00,  1.22it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:   0% 0/24 [00:00<?, ?it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:   4% 1/24 [00:00<00:17,  1.34it/s]
# Compressing /encoder/layer.3/output/dense/MatMul: 100% 96/96 [01:27<00:00,  1.10it/s]
#
# Compressing /encoder/layer.4/attention/output/dense/MatMul:   8% 2/24 [00:01<00:16,  1.32it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  12% 3/24 [00:02<00:15,  1.33it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  17% 4/24 [00:03<00:15,  1.33it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  21% 5/24 [00:03<00:14,  1.34it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  25% 6/24 [00:04<00:13,  1.32it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  29% 7/24 [00:05<00:15,  1.10it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  33% 8/24 [00:06<00:13,  1.17it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  38% 9/24 [00:07<00:12,  1.18it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  42% 10/24 [00:08<00:11,  1.21it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  46% 11/24 [00:08<00:10,  1.20it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  50% 12/24 [00:09<00:10,  1.14it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  54% 13/24 [00:10<00:09,  1.11it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  58% 14/24 [00:11<00:09,  1.08it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  62% 15/24 [00:12<00:08,  1.06it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  67% 16/24 [00:13<00:07,  1.06it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  71% 17/24 [00:14<00:06,  1.05it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  75% 18/24 [00:15<00:05,  1.06it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  79% 19/24 [00:16<00:04,  1.12it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  83% 20/24 [00:17<00:03,  1.19it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  88% 21/24 [00:17<00:02,  1.24it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  92% 22/24 [00:18<00:01,  1.28it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  96% 23/24 [00:19<00:00,  1.30it/s]
# Compressing /encoder/layer.4/attention/output/dense/MatMul: 100% 24/24 [00:20<00:00,  1.19it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:   0% 0/96 [00:00<?, ?it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:   1% 1/96 [00:00<01:12,  1.30it/s]
# Compressing /encoder/layer.4/intermediate/dense/MatMul: 100% 24/24 [00:20<00:00,  1.18it/s]
#
# Compressing /encoder/layer.4/output/dense/MatMul:   2% 2/96 [00:01<01:10,  1.33it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:   3% 3/96 [00:02<01:10,  1.32it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:   4% 4/96 [00:02<01:08,  1.35it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:   5% 5/96 [00:03<01:07,  1.36it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:   6% 6/96 [00:04<01:06,  1.34it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:   7% 7/96 [00:05<01:06,  1.34it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:   8% 8/96 [00:06<01:08,  1.29it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:   9% 9/96 [00:06<01:08,  1.27it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  10% 10/96 [00:07<01:09,  1.24it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  11% 11/96 [00:08<01:12,  1.17it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  12% 12/96 [00:09<01:14,  1.13it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  14% 13/96 [00:10<01:15,  1.09it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  15% 14/96 [00:11<01:16,  1.06it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  16% 15/96 [00:12<01:16,  1.06it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  17% 16/96 [00:13<01:16,  1.04it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  18% 17/96 [00:14<01:14,  1.07it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  19% 18/96 [00:15<01:08,  1.14it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  20% 19/96 [00:15<01:05,  1.18it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  21% 20/96 [00:16<01:03,  1.20it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  22% 21/96 [00:17<01:00,  1.23it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  23% 22/96 [00:18<00:59,  1.25it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  24% 23/96 [00:19<00:57,  1.27it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  25% 24/96 [00:19<00:55,  1.29it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  26% 25/96 [00:20<00:54,  1.31it/s]
# Compressing /encoder/layer.5/attention/self/key/MatMul: 100% 24/24 [00:19<00:00,  1.20it/s]
#
# Compressing /encoder/layer.4/output/dense/MatMul:  27% 26/96 [00:21<00:53,  1.31it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  28% 27/96 [00:22<00:52,  1.32it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  29% 28/96 [00:22<00:51,  1.33it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  30% 29/96 [00:23<00:50,  1.33it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  31% 30/96 [00:24<00:49,  1.33it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  32% 31/96 [00:25<00:50,  1.30it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  33% 32/96 [00:25<00:50,  1.27it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  34% 33/96 [00:26<00:51,  1.22it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  35% 34/96 [00:27<00:54,  1.15it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  36% 35/96 [00:28<00:55,  1.10it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  38% 36/96 [00:29<00:55,  1.08it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  39% 37/96 [00:30<00:55,  1.06it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  40% 38/96 [00:31<00:55,  1.04it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  41% 39/96 [00:32<00:55,  1.03it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  42% 40/96 [00:33<00:51,  1.09it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  43% 41/96 [00:34<00:47,  1.15it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  44% 42/96 [00:35<00:44,  1.21it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  45% 43/96 [00:35<00:42,  1.24it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  46% 44/96 [00:36<00:41,  1.25it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  47% 45/96 [00:37<00:40,  1.26it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  48% 46/96 [00:38<00:39,  1.27it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  49% 47/96 [00:38<00:37,  1.29it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  50% 48/96 [00:39<00:36,  1.30it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  51% 49/96 [00:40<00:36,  1.30it/s]
# Compressing /encoder/layer.5/attention/self/query/MatMul: 100% 24/24 [00:19<00:00,  1.21it/s]
#
# Compressing /encoder/layer.4/output/dense/MatMul:  52% 50/96 [00:41<00:35,  1.31it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  53% 51/96 [00:41<00:34,  1.32it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  54% 52/96 [00:42<00:33,  1.32it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  55% 53/96 [00:43<00:33,  1.30it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  56% 54/96 [00:44<00:32,  1.29it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  57% 55/96 [00:45<00:32,  1.27it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  58% 56/96 [00:46<00:33,  1.19it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  59% 57/96 [00:46<00:34,  1.14it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  60% 58/96 [00:47<00:34,  1.09it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  61% 59/96 [00:48<00:34,  1.07it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  62% 60/96 [00:49<00:34,  1.04it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  64% 61/96 [00:50<00:33,  1.03it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  65% 62/96 [00:51<00:32,  1.04it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  66% 63/96 [00:52<00:29,  1.11it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  67% 64/96 [00:53<00:27,  1.16it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  68% 65/96 [00:54<00:25,  1.21it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  69% 66/96 [00:54<00:24,  1.24it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  70% 67/96 [00:55<00:22,  1.26it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  71% 68/96 [00:56<00:21,  1.29it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  72% 69/96 [00:57<00:23,  1.14it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  73% 70/96 [00:58<00:22,  1.17it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  74% 71/96 [00:59<00:20,  1.22it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  75% 72/96 [00:59<00:19,  1.25it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  76% 73/96 [01:00<00:18,  1.27it/s]
# Compressing /encoder/layer.5/attention/self/value/MatMul: 100% 24/24 [00:20<00:00,  1.19it/s]
#
# Compressing /encoder/layer.4/output/dense/MatMul:  78% 75/96 [01:02<00:16,  1.31it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  79% 76/96 [01:02<00:15,  1.28it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  80% 77/96 [01:03<00:15,  1.26it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  81% 78/96 [01:04<00:15,  1.19it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  82% 79/96 [01:05<00:14,  1.14it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  83% 80/96 [01:06<00:14,  1.10it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  84% 81/96 [01:07<00:14,  1.07it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  85% 82/96 [01:08<00:13,  1.05it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  86% 83/96 [01:09<00:12,  1.04it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  88% 84/96 [01:10<00:11,  1.06it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  89% 85/96 [01:11<00:09,  1.14it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  90% 86/96 [01:11<00:08,  1.20it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  91% 87/96 [01:12<00:07,  1.23it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  92% 88/96 [01:13<00:06,  1.26it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  93% 89/96 [01:14<00:05,  1.28it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  94% 90/96 [01:15<00:04,  1.27it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  95% 91/96 [01:15<00:03,  1.27it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  96% 92/96 [01:16<00:03,  1.28it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  97% 93/96 [01:17<00:02,  1.31it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  98% 94/96 [01:18<00:01,  1.30it/s]
# Compressing /encoder/layer.4/output/dense/MatMul:  99% 95/96 [01:18<00:00,  1.31it/s]
# Compressing /encoder/layer.4/output/dense/MatMul: 100% 96/96 [01:19<00:00,  1.21it/s]
# Compressing /encoder/layer.5/intermediate/dense/MatMul:   0% 0/24 [00:00<?, ?it/s]
# Compressing /encoder/layer.5/intermediate/dense/MatMul:   4% 1/24 [00:00<00:16,  1.36it/s]
# Compressing /encoder/layer.5/intermediate/dense/MatMul:   8% 2/24 [00:01<00:17,  1.25it/s]
# Compressing /encoder/layer.5/attention/output/dense/MatMul: 100% 24/24 [00:20<00:00,  1.20it/s]
# Compressing /encoder/layer.5/intermediate/dense/MatMul: 100% 24/24 [00:11<00:00,  2.13it/s]
# INFO:sparsifyml.one_shot.sparsification.obcq.fast_obcq_modifier:Compressed model to effective overall sparsity of 0.47872029999156057. Full sparsity profile saved to experiments/20230828-135207/OBCQ/effective_sparsity_profile.json
# INFO:sparsifyml.one_shot.sparsification.obcq.fast_obcq_modifier:Running min/max calibration against dataset on 48 network activations
# INFO:sparsifyml.one_shot.sparsification.obcq.fast_obcq_modifier:Calibration complete
# INFO:sparsifyml.one_shot.sparsification.quantization.qdq:Injected Q/DQ blocks for 36 weights and 60 activations
# 2023-08-28 14:03:00 sparseml.exporters.transforms.onnx_transform INFO     [ConstantsToInitializers] Transformed 147 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[ConstantsToInitializers] Transformed 147 matches
# 2023-08-28 14:03:00 sparseml.exporters.transforms.onnx_transform INFO     [FoldIdentityInitializers] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[FoldIdentityInitializers] Transformed 0 matches
# 2023-08-28 14:03:00 sparseml.exporters.transforms.onnx_transform INFO     [InitializersToUint8] Transformed 84 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[InitializersToUint8] Transformed 84 matches
# 2023-08-28 14:03:01 sparseml.exporters.transforms.onnx_transform INFO     [FlattenQParams] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[FlattenQParams] Transformed 0 matches
# 2023-08-28 14:03:01 sparseml.exporters.transforms.onnx_transform INFO     [FoldConvDivBn] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[FoldConvDivBn] Transformed 0 matches
# 2023-08-28 14:03:01 sparseml.exporters.transforms.onnx_transform INFO     [DeleteRepeatedQdq] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[DeleteRepeatedQdq] Transformed 0 matches
# 2023-08-28 14:03:02 sparseml.exporters.transforms.onnx_transform INFO     [QuantizeQATEmbedding] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[QuantizeQATEmbedding] Transformed 0 matches
# 2023-08-28 14:03:02 sparseml.exporters.transforms.onnx_transform INFO     [PropagateEmbeddingQuantization] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[PropagateEmbeddingQuantization] Transformed 0 matches
# 2023-08-28 14:03:02 sparseml.exporters.transforms.onnx_transform INFO     [PropagateDequantThroughSplit] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[PropagateDequantThroughSplit] Transformed 0 matches
# 2023-08-28 14:03:02 sparseml.exporters.transforms.onnx_transform INFO     [MatMulToQLinearMatMul] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[MatMulToQLinearMatMul] Transformed 0 matches
# 2023-08-28 14:03:03 sparseml.exporters.transforms.onnx_transform INFO     [MatMulAddToMatMulIntegerAddCastMul] Transformed 36 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[MatMulAddToMatMulIntegerAddCastMul] Transformed 36 matches
# 2023-08-28 14:03:03 sparseml.exporters.transforms.onnx_transform INFO     [MatMulToMatMulIntegerCastMul] Transformed 12 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[MatMulToMatMulIntegerCastMul] Transformed 12 matches
# 2023-08-28 14:03:04 sparseml.exporters.transforms.onnx_transform INFO     [FoldReLUQuants] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[FoldReLUQuants] Transformed 0 matches
# 2023-08-28 14:03:04 sparseml.exporters.transforms.onnx_transform INFO     [ConvToConvIntegerAddCastMul] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[ConvToConvIntegerAddCastMul] Transformed 0 matches
# 2023-08-28 14:03:04 sparseml.exporters.transforms.onnx_transform INFO     [GemmToQLinearMatMul] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[GemmToQLinearMatMul] Transformed 0 matches
# 2023-08-28 14:03:04 sparseml.exporters.transforms.onnx_transform INFO     [GemmToMatMulIntegerAddCastMul] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[GemmToMatMulIntegerAddCastMul] Transformed 0 matches
# 2023-08-28 14:03:05 sparseml.exporters.transforms.onnx_transform INFO     [QuantizeResiduals] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[QuantizeResiduals] Transformed 0 matches
# 2023-08-28 14:03:05 sparseml.exporters.transforms.onnx_transform INFO     [RemoveDuplicateQConvWeights] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[RemoveDuplicateQConvWeights] Transformed 0 matches
# 2023-08-28 14:03:05 sparseml.exporters.transforms.onnx_transform INFO     [RemoveDuplicateQuantizeOps] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[RemoveDuplicateQuantizeOps] Transformed 0 matches
# INFO:sparsify.run one_shot: Model saved to deployment directory: /content/deployment

# %%
# !mv deployment sparse_onnx
# !cp dense_onnx/tokenizer.json sparse_onnx/
# !cp dense_onnx/config.json sparse_onnx/

# %% [markdown]
# ## Creating an Inference Pipeline for Sentence Embeddings
#
# Let's now create a sentence embedding inference pipeline using PyTorch and the Hugging Face Pipeline for pooling in post-processing. We'll need this in order to evaluate the performance of the models using the `evaluate` library and the upcoming `weaviate` deployment using sentence embeddings.

# %%
from transformers import Pipeline
import torch.nn.functional as F
import torch


def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0]
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

class SentenceEmbeddingPipeline(Pipeline):
    def _sanitize_parameters(self, **kwargs):
        preprocess_kwargs = {}
        return preprocess_kwargs, {}, {}

    def preprocess(self, inputs):
        encoded_inputs = self.tokenizer(inputs, padding=True, truncation=True, return_tensors='pt')
        return encoded_inputs

    def _forward(self, model_inputs):
        outputs = self.model(**model_inputs)
        return {"outputs": outputs, "attention_mask": model_inputs["attention_mask"]}

    def postprocess(self, model_outputs):
        # Perform pooling
        sentence_embeddings = mean_pooling(model_outputs["outputs"], model_outputs['attention_mask'])
        # Normalize embeddings
        sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)
        return sentence_embeddings

# %% [markdown]
# Initialize model pipelines, and double check if they work for both the dense and sparse models.

# %%
dense = "dense_onnx"
sparse = "sparse_onnx"

dense_model = DeepSparseModelForFeatureExtraction.from_pretrained(dense, export=False)
tokenizer = get_preprocessor(dense)

sparse_model = DeepSparseModelForFeatureExtraction.from_pretrained(sparse, export=False)
tokenizer = get_preprocessor(sparse)

dense_pipe = SentenceEmbeddingPipeline(model=dense_model, tokenizer=tokenizer)
sparse_pipe = SentenceEmbeddingPipeline(model=sparse_model, tokenizer=tokenizer)

sample_text = "I love sparse sentence embedding models"

dense_infer = dense_pipe(sample_text)
sparse_infer = sparse_pipe(sample_text)

# print an excerpt from the sentence embedding
print(dense_infer[0][:5])
print(sparse_infer[0][:5])
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Model is dynamic and has no shapes defined, skipping reshape..
# Model is dynamic and has no shapes defined, skipping reshape..
# tensor([ 0.0041, -0.1259,  0.0277,  0.0237,  0.0413])
# tensor([-0.0051, -0.0665,  0.0314,  0.0038, -0.0135])

# %% [markdown]
# ## Evaluate the Dense vs. Sparse Model for Accuracy on STSB

# %%
from datasets import load_dataset
from evaluate import load
import torch

eval_dataset = load_dataset("glue","stsb",split="validation")
metric = load('glue', 'stsb')

def compute_sentence_similarity(sentence_1, sentence_2,pipeline):
    embedding_1 = pipeline(sentence_1)
    embedding_2 = pipeline(sentence_2)

    return torch.nn.functional.cosine_similarity(embedding_1, embedding_2, dim=1)

def evaluate_stsb(example):
  default = compute_sentence_similarity(example["sentence1"], example["sentence2"], dense_pipe)
  sparse = compute_sentence_similarity(example["sentence1"], example["sentence2"], sparse_pipe)
  return {
      'reference': (example["label"] - 1) / (5 - 1),
      'default': float(default),
      'sparse': float(sparse),
      }

# run evaluation
result = eval_dataset.map(evaluate_stsb)

# compute metrics
default_acc = metric.compute(predictions=result["default"], references=result["reference"])
sparse = metric.compute(predictions=result["sparse"], references=result["reference"])

print(f"dense model: pearson={default_acc['pearson']}%")
print(f"sparse model: pearson={sparse['pearson']}%")
print(f"The sparse model achieves {round(sparse['pearson']/default_acc['pearson'],2)*100:.2f}% accuracy of the dense model")
# Out:
# Downloading builder script:   0%|          | 0.00/5.75k [00:00<?, ?B/s]
# Parameter 'function'=<function evaluate_stsb at 0x7b01bff643a0> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# WARNING:datasets.fingerprint:Parameter 'function'=<function evaluate_stsb at 0x7b01bff643a0> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# Map:   0%|          | 0/1500 [00:00<?, ? examples/s]
# dense model: pearson=0.8696194668251013%
# sparse model: pearson=0.8483653311696123%
# The sparse model achieves 98.00% accuracy of the dense model

# %% [markdown]
# ## Benchmark the Dense vs. Sparse Model for Latency

# %%
from time import perf_counter
import numpy as np

payload = "Greetings, I'm Jane the robot, residing in the vibrant city of Seattle, USA. " \
"My journey involves crafting innovative solutions as a Software Architect, " \
"driving technological progress through collaborative endeavors and cutting-edge research. " \
"My experience spans across diverse domains, from optimizing supply chain logistics " \
"to enhancing medical diagnostics. Passionate about exploring AI ethics and " \
"the human-machine partnership, I'm constantly evolving to pioneer the future of technology."


print(f'Payload sequence length: {len(tokenizer(payload)["input_ids"])}')

def measure_latency(pipe):
    latencies = []
    # warm up
    for _ in range(10):
        _ = pipe(payload)
    # Timed run
    for _ in range(100):
        start_time = perf_counter()
        _ =  pipe(payload)
        latency = perf_counter() - start_time
        latencies.append(latency)
    # Compute run statistics
    time_avg_ms = 1000 * np.mean(latencies)
    time_std_ms = 1000 * np.std(latencies)
    time_p95_ms = 1000 * np.percentile(latencies,95)
    return f"P95 latency (ms) - {time_p95_ms}; Average latency (ms) - {time_avg_ms:.2f} +\- {time_std_ms:.2f};", time_p95_ms

vanilla_model=measure_latency(dense_pipe)
quantized_model=measure_latency(sparse_pipe)

print(f"dense model: {vanilla_model[0]}")
print(f"quantized model: {quantized_model[0]}")
print(f"Improvement through one-shot: {round(vanilla_model[1]/quantized_model[1],2)}x")
# Out:
# Payload sequence length: 90
# dense model: P95 latency (ms) - 55.83691190004174; Average latency (ms) - 49.65 +\- 2.85;
# quantized model: P95 latency (ms) - 46.095011049874294; Average latency (ms) - 31.63 +\- 5.87;
# Improvement through one-shot: 1.21x

# %% [markdown]
# ## Connect to Weaviate Client
#
# Replace `url` and `api_key` with your Weaviate credentials.

# %%
import torch
from transformers import AutoModel, AutoTokenizer
import weaviate
import time

# initialize weaviate client for importing and searching
client = weaviate.Client(
    url = "https://sparse-minilm-j8lqfvbq.weaviate.network",  # Replace with your endpoint
    auth_client_secret=weaviate.AuthApiKey(api_key="5ulTIjYyHCK3LvT6dJzlV8qaeEozWsHQVwX5"),  # Replace w/ your Weaviate instance API key
)

# %% [markdown]
# # Preprocess Dataset
#
# Let's preprocess the 20 Newsgroups dataset for cleaning by removing headers, filtering out short posts, and replacing characters.

# %%
import os
import random

def get_post_filenames(limit_objects=100):
    file_names = []
    i=0
    for root, dirs, files in os.walk("./data/20news-bydate-test"):
        for filename in files:
            path = os.path.join(root, filename)
            file_names += [path]

    random.shuffle(file_names)
    limit_objects = min(len(file_names), limit_objects)

    file_names = file_names[:limit_objects]

    return file_names

def read_posts(filenames=[]):
    posts = []
    for filename in filenames:
        f = open(filename, encoding="utf-8", errors='ignore')
        post = f.read()

        # strip the headers (the first occurrence of two newlines)
        post = post[post.find('\n\n'):]

        # remove posts with less than 10 words to remove some of the noise
        if len(post.split(' ')) < 10:
               continue

        post = post.replace('\n', ' ').replace('\t', ' ')
        if len(post) > 1000:
            post = post[:1000]
        posts += [post]

    return posts

# %% [markdown]
# ## Vectorize Posts from Dataset Using MiniLM

# %%
def vectorize_posts(posts=[]):
    post_vectors = []
    before = time.perf_counter()
    for i, post in enumerate(posts):
        vec = sparse_pipe(post)
        post_vectors.append(vec)
        if i % 25 == 0 and i != 0:
            print("So far {} objects vectorized in {:.3f}s".format(i, time.perf_counter() - before))
    after = time.perf_counter()

    print("Vectorized {} items in {:.3f}s".format(len(posts), after - before))

    return post_vectors

# %% [markdown]
# ## Create Weaviate Schema

# %%
def init_weaviate_schema(client):
    # a simple schema containing just a single class for our posts
    schema = {
        "classes": [{
                "class": "Post",
                "vectorizer": "none", # explicitly tell Weaviate not to vectorize anything, we are providing the vectors ourselves through our MiniLM model
                "properties": [{
                    "name": "content",
                    "dataType": ["text"],
                }]
        }]
    }

    # cleanup from previous runs
    client.schema.delete_all()
    client.schema.create(schema)

# %%
def import_posts_with_vectors(posts, vectors, client):
    if len(posts) != len(vectors):
        raise Exception("len of posts ({}) and vectors ({}) does not match".format(len(posts), len(vectors)))

    for i, post in enumerate(posts):
        try:
            client.data_object.create(
                data_object={"content": post},
                class_name='Post',
                vector=vectors[i]
            )
        except:
            print(res)

# %%
def search(query="", limit=3):
    vec_took_start = time.perf_counter()
    vec = sparse_pipe(query)
    vec_took = time.perf_counter() - vec_took_start

    search_took_start = time.perf_counter()
    near_vec = {"vector": vec}
    res = client \
        .query.get("Post", ["content", "_additional {certainty}"]) \
        .with_near_vector(near_vec) \
        .with_limit(limit) \
        .do()
    search_took = time.perf_counter() - search_took_start

    total_time = vec_took + search_took

    print("\nQuery \"{}\" with {} results took {:.3f}s ({:.3f}s to vectorize and {:.3f}s to search)" \
          .format(query, limit, total_time, vec_took, search_took))

    for post in res["data"]["Get"]["Post"]:
        print("{:.4f}: {}".format(post["_additional"]["certainty"], post["content"]))
        print('---')

# %%
init_weaviate_schema(client)
posts = read_posts(get_post_filenames(100))
vectors = vectorize_posts(posts)
import_posts_with_vectors(posts, vectors, client)
# Out:
# Vectorized 0 items in 0.000s

# %%
search("the best camera lens", 1)
search("motorcycle trip", 1)
search("which software do i need to view jpeg files", 1)
search("windows vs mac", 1)
# Out:
# Query "the best camera lens" with 1 results took 0.153s (0.009s to vectorize and 0.144s to search)
#
# Query "motorcycle trip" with 1 results took 0.144s (0.005s to vectorize and 0.139s to search)
#
# Query "which software do i need to view jpeg files" with 1 results took 0.146s (0.007s to vectorize and 0.139s to search)
#
# Query "windows vs mac" with 1 results took 0.146s (0.005s to vectorize and 0.140s to search)
