# %% [markdown]
# # Sparsifying the BGE-Small Model for Embeddings
#
# BGE models are currently state-of-the-art models for embeddings on the [MTEB Leaderboard](https://huggingface.co/spaces/mteb/leaderboard). In this notebook, we will sparsify the [bge-small-en-v1.5](https://huggingface.co/BAAI/bge-small-en-v1.5) model using [Sparsify's](https://github.com/neuralmagic/sparsify) INT8 quantization via its one-shot method. We will also evaluate its accuracy and speed improvements vs. its dense variant after sparsification.To learn more about one-shot, refer to this [guide](https://github.com/neuralmagic/sparsify/blob/main/docs/one-shot-experiment-guide.md).

# %%
# !pip install -U deepsparse-nightly[sentence_transformers] -q
# !pip install git+https://github.com/neuralmagic/sparsify.git -q
# !pip install sentence-transformers evaluate -q

# %% [markdown]
# # Optimum DeepSparse
#
# In order to use the Dense BGE model in Sparsify, we first have to convert it into ONNX using the Optimum DeepSparse library.

# %%
from optimum.deepsparse import DeepSparseModelForFeatureExtraction
from transformers.onnx.utils import get_preprocessor
from pathlib import Path

model_id = "BAAI/bge-small-en-v1.5"

# load model and convert to onnx
model = DeepSparseModelForFeatureExtraction.from_pretrained(model_id, export=True)
tokenizer = get_preprocessor(model_id)

# save onnx checkpoint and tokenizer
onnx_path = Path("bge-small-en-v1.5-dense")
model.save_pretrained(onnx_path)
tokenizer.save_pretrained(onnx_path)
# Out:
# Framework not specified. Using pt to export to ONNX.
# Using the export variant default. Available variants are:
# 	- default: The default ONNX variant.
# Using framework PyTorch: 2.0.0+cu117
# Overriding 1 configuration item(s)
# 	- use_cache -> False
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# ('bge-small-en-v1.5-dense/tokenizer_config.json',
#  'bge-small-en-v1.5-dense/special_tokens_map.json',
#  'bge-small-en-v1.5-dense/vocab.txt',
#  'bge-small-en-v1.5-dense/added_tokens.json',
#  'bge-small-en-v1.5-dense/tokenizer.json')

# %% [markdown]
# # Create NPZ files
#
# Sparsify's One-Shot is a post-training sparsification method that utilizes sampled data (~1,000 samples is satisfactory) from a calibration dataset resulting in no further training time and much faster sparsification times compared with Training-Aware Experiments.
#
# The samples need to be stored in the .npz format, which is a file format based on the NumPy library. In the BERT model architecture (such as in the BGE models), Sparsify one-shot requires the input_ids, attention_mask and token_type_ids of each data sample from your dataset to be stored as a dictionary prior to .npz storage. For more information, refer to the Sparsify guide.
#
# For our example, we'll use the popular semantic textual similarity benchmark (stsb) dataset for calibration. Now, let's extract 1,000 samples from the train split and convert them to .npz:

# %%
import os
import numpy as np
from datasets import load_dataset
from sentence_transformers import InputExample

# Load the dataset
dataset = load_dataset("glue", "stsb", split="train")

# Adjusted to get the first 1000 examples
n_examples = 1000

# Create the "data" directory if it doesn't exist
if not os.path.exists('data'):
    os.makedirs('data')

# Define a function to create NPZ dictionaries
def create_npz_data(texts, index):
    # Tokenize the texts
    inputs = tokenizer(texts, padding=True, truncation=True, max_length=512, return_tensors='pt')

    # Extract input_ids, attention_mask, and token_type_ids
    input_ids = inputs['input_ids'].cpu().numpy()[0]
    attention_mask = inputs['attention_mask'].cpu().numpy()[0]
    token_type_ids = inputs.get('token_type_ids', None)
    if token_type_ids is not None:
        token_type_ids = token_type_ids.cpu().numpy()[0]

    # Create the NPZ dictionary
    npz_data = {
        "input_ids": input_ids,
        "attention_mask": attention_mask,
        "token_type_ids": token_type_ids if token_type_ids is not None else np.array([]),  # Handle cases where token_type_ids are not present
    }

    # Save the dictionary as an NPZ file
    npz_file_path = f'data/input_{index:04d}.npz'
    np.savez(npz_file_path, **npz_data)

# Create NPZ dictionaries and save them individually
train_examples = []
for i in range(n_examples):

    example = dataset[i]
    train_examples.append(InputExample(texts=[example['sentence1'], example['sentence2']]))

    # Extract texts from InputExample instances
    texts = [example.texts for example in train_examples]

    # Create the NPZ dictionary and save it
    create_npz_data(texts, i)

print(f'Saved {n_examples} npz files to data/')
# Out:
# Saved 1000 npz files to data/

# %% [markdown]
# # Login to Sparsify

# %%
# !sparsify.login EJMfcp88Wpp7efA99WjAfSAFH6jhwfG9
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# INFO:sparsify.login:Logging into sparsify...
# INFO:sparsify.utils.helpers:Successfully authenticated with Neural Magic Account API key
# INFO:sparsify.login:sparsifyml version 1.6 is already installed, skipping installation from neuralmagic pypi server
# INFO:sparsify.login:Logged in successfully, sparsify setup is complete.

# %% [markdown]
# # Run Sparsify One-Shot
#
# Pass the model directory and set optim-level to 0.2 which initiate quantization with a single CLI command:

# %%
# !sparsify.run one-shot --use-case nlp-embeddings --model ./bge-small-en-v1.5-dense/model.onnx --data ./data --optim-level 0.2
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# WARNING:sparsify.cli.opts:Unknown use-case nlp-embeddings, full feature set may not be availble for custom use cases
# INFO:sparsify.utils.helpers:Successfully authenticated with Neural Magic Account API key
# INFO:sparsify.login:sparsifyml version 1.6 is already installed, skipping installation from neuralmagic pypi server
# WARNING:sparsify.check_environment.gpu_device:Checking for GPU...
# WARNING:sparsify.check_environment.gpu_device:GPU check completed successfully
# WARNING:sparsify.check_environment.ort_health:Checking onnxruntime-gpu environment health...
# 2023-11-14 09:18:47 deepsparse.utils.onnx INFO     Generating input 'X', type = float32, shape = [1, 3, 32, 32]
# INFO:deepsparse.utils.onnx:Generating input 'X', type = float32, shape = [1, 3, 32, 32]
# WARNING:sparsify.check_environment.ort_health:onnxruntime-gpu environment check completed successfully
# INFO:sparsifyml.one_shot.sparsification.obcq.fast_obcq_modifier:Folded 0 Conv-BatchNormalization blocks
# INFO:sparsifyml.one_shot.sparsification.obcq.base_obcq_modifier:FastOBCQModifier: starting compression on layers: ['/encoder/layer.0/attention/self/query/MatMul', '/encoder/layer.0/attention/self/value/MatMul', '/encoder/layer.0/attention/output/dense/MatMul', '/encoder/layer.0/intermediate/dense/MatMul', '/encoder/layer.0/output/dense/MatMul', '/encoder/layer.1/attention/self/key/MatMul', '/encoder/layer.1/attention/self/query/MatMul', '/encoder/layer.1/attention/self/value/MatMul', '/encoder/layer.1/attention/output/dense/MatMul', '/encoder/layer.1/intermediate/dense/MatMul', '/encoder/layer.1/output/dense/MatMul', '/encoder/layer.2/attention/self/key/MatMul', '/encoder/layer.2/attention/self/query/MatMul', '/encoder/layer.2/attention/self/value/MatMul', '/encoder/layer.2/attention/output/dense/MatMul', '/encoder/layer.2/intermediate/dense/MatMul', '/encoder/layer.2/output/dense/MatMul', '/encoder/layer.3/attention/self/key/MatMul', '/encoder/layer.3/attention/self/query/MatMul', '/encoder/layer.3/attention/self/value/MatMul', '/encoder/layer.3/attention/output/dense/MatMul', '/encoder/layer.3/intermediate/dense/MatMul', '/encoder/layer.3/output/dense/MatMul', '/encoder/layer.4/attention/self/key/MatMul', '/encoder/layer.4/attention/self/query/MatMul', '/encoder/layer.4/attention/self/value/MatMul', '/encoder/layer.4/attention/output/dense/MatMul', '/encoder/layer.4/intermediate/dense/MatMul', '/encoder/layer.4/output/dense/MatMul', '/encoder/layer.5/attention/self/key/MatMul', '/encoder/layer.5/attention/self/query/MatMul', '/encoder/layer.5/attention/self/value/MatMul', '/encoder/layer.5/attention/output/dense/MatMul', '/encoder/layer.5/intermediate/dense/MatMul', '/encoder/layer.5/output/dense/MatMul', '/encoder/layer.6/attention/self/key/MatMul', '/encoder/layer.6/attention/self/query/MatMul', '/encoder/layer.6/attention/self/value/MatMul', '/encoder/layer.6/attention/output/dense/MatMul', '/encoder/layer.6/intermediate/dense/MatMul', '/encoder/layer.6/output/dense/MatMul', '/encoder/layer.7/attention/self/key/MatMul', '/encoder/layer.7/attention/self/query/MatMul', '/encoder/layer.7/attention/self/value/MatMul', '/encoder/layer.7/attention/output/dense/MatMul', '/encoder/layer.7/intermediate/dense/MatMul', '/encoder/layer.7/output/dense/MatMul', '/encoder/layer.8/attention/self/key/MatMul', '/encoder/layer.8/attention/self/query/MatMul', '/encoder/layer.8/attention/self/value/MatMul', '/encoder/layer.8/attention/output/dense/MatMul', '/encoder/layer.8/intermediate/dense/MatMul', '/encoder/layer.8/output/dense/MatMul', '/encoder/layer.9/attention/self/key/MatMul', '/encoder/layer.9/attention/self/query/MatMul', '/encoder/layer.9/attention/self/value/MatMul', '/encoder/layer.9/attention/output/dense/MatMul', '/encoder/layer.9/intermediate/dense/MatMul', '/encoder/layer.9/output/dense/MatMul', '/encoder/layer.10/attention/self/key/MatMul', '/encoder/layer.10/attention/self/query/MatMul', '/encoder/layer.10/attention/self/value/MatMul', '/encoder/layer.10/attention/output/dense/MatMul', '/encoder/layer.10/intermediate/dense/MatMul', '/encoder/layer.10/output/dense/MatMul', '/encoder/layer.11/attention/self/key/MatMul', '/encoder/layer.11/attention/self/query/MatMul', '/encoder/layer.11/attention/self/value/MatMul', '/encoder/layer.11/attention/output/dense/MatMul', '/encoder/layer.11/intermediate/dense/MatMul']
# Calibration: 1001it [01:17, 12.93it/s]
# INFO:sparsifyml.one_shot.sparsification.obcq.base_obcq_modifier:saving H estimates to experiments/20231114-091852/OBCQ/H_estimates
# WARNING:/home/zeroshot/nm/examples/env/lib/python3.10/site-packages/sparsifyml/one_shot/sparsification/obcq/utils/compression.py:H inversion failed with original dampening fraction of 0.001. It eventually succeeded with dampening fraction of 0.01
# Compressing /encoder/layer.0/attention/self/query/MatMul:   0%| | 0/24 [00:00<?,
# Compressing /encoder/layer.0/attention/self/value/MatMul:   0%| | 0/24 [00:00<?,
# Compressing /encoder/layer.0/attention/self/query/MatMul:   4%| | 1/24 [00:02<00
# Compressing /encoder/layer.0/attention/self/query/MatMul:   8%| | 2/24 [00:04<00
# Compressing /encoder/layer.0/attention/self/query/MatMul:  12%|▏| 3/24 [00:06<00
# Compressing /encoder/layer.0/attention/self/query/MatMul:  17%|▏| 4/24 [00:08<00
# Compressing /encoder/layer.0/attention/self/query/MatMul:  21%|▏| 5/24 [00:10<00
# Compressing /encoder/layer.0/attention/self/query/MatMul:  25%|▎| 6/24 [00:13<00
# Compressing /encoder/layer.0/attention/self/query/MatMul:  29%|▎| 7/24 [00:15<00
# Compressing /encoder/layer.0/attention/self/query/MatMul:  33%|▎| 8/24 [00:17<00
# Compressing /encoder/layer.0/attention/self/query/MatMul:  38%|▍| 9/24 [00:19<00
# Compressing /encoder/layer.0/attention/self/query/MatMul:  42%|▍| 10/24 [00:21<0
# Compressing /encoder/layer.0/attention/self/query/MatMul:  46%|▍| 11/24 [00:23<0
# Compressing /encoder/layer.0/attention/self/query/MatMul:  50%|▌| 12/24 [00:25<0
# Compressing /encoder/layer.0/attention/self/query/MatMul:  54%|▌| 13/24 [00:27<0
# Compressing /encoder/layer.0/attention/self/value/MatMul:  58%|▌| 14/24 [00:28<0
# Compressing /encoder/layer.0/attention/self/query/MatMul:  58%|▌| 14/24 [00:30<0
# Compressing /encoder/layer.0/attention/self/query/MatMul:  62%|▋| 15/24 [00:32<0
# Compressing /encoder/layer.0/attention/self/query/MatMul:  67%|▋| 16/24 [00:34<0
# Compressing /encoder/layer.0/attention/self/query/MatMul:  71%|▋| 17/24 [00:36<0
# Compressing /encoder/layer.0/attention/self/query/MatMul:  75%|▊| 18/24 [00:38<0
# Compressing /encoder/layer.0/attention/self/query/MatMul:  79%|▊| 19/24 [00:40<0
# Compressing /encoder/layer.0/attention/self/query/MatMul:  83%|▊| 20/24 [00:42<0
# Compressing /encoder/layer.0/attention/self/query/MatMul:  88%|▉| 21/24 [00:45<0
# Compressing /encoder/layer.0/attention/self/query/MatMul:  92%|▉| 22/24 [00:47<0
# Compressing /encoder/layer.0/attention/self/value/MatMul: 100%|█| 24/24 [00:48<0
#
# Compressing /encoder/layer.0/attention/self/query/MatMul:  96%|▉| 23/24 [00:49<0
# Compressing /encoder/layer.0/attention/self/query/MatMul: 100%|█| 24/24 [00:51<0
# Compressing /encoder/layer.0/intermediate/dense/MatMul:   0%| | 0/24 [00:00<?, ?
# Compressing /encoder/layer.0/intermediate/dense/MatMul:   4%| | 1/24 [00:02<00:4
# Compressing /encoder/layer.0/intermediate/dense/MatMul:   8%| | 2/24 [00:04<00:4
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  12%|▏| 3/24 [00:06<00:4
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  21%|▏| 5/24 [00:09<
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  17%|▏| 4/24 [00:08<00:4
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  21%|▏| 5/24 [00:11<00:4
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  25%|▎| 6/24 [00:13<00:4
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  29%|▎| 7/24 [00:15<00:3
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  33%|▎| 8/24 [00:17<00:3
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  38%|▍| 9/24 [00:19<00:3
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  50%|▌| 12/24 [00:23
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  42%|▍| 10/24 [00:22<00:
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  46%|▍| 11/24 [00:24<00:
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  50%|▌| 12/24 [00:27<00:
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  54%|▌| 13/24 [00:29<00:
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  71%|▋| 17/24 [00:33
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  62%|▋| 15/24 [00:33<00:
# Compressing /encoder/layer.0/attention/output/dense/MatMul:  79%|▊| 19/24 [00:37
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  67%|▋| 16/24 [00:35<00:
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  71%|▋| 17/24 [00:38<00:
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  75%|▊| 18/24 [00:40<00:
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  79%|▊| 19/24 [00:42<00:
# Compressing /encoder/layer.0/attention/output/dense/MatMul: 100%|█| 24/24 [00:47
#
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  83%|▊| 20/24 [00:44<00:
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  88%|▉| 21/24 [00:46<00:
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  92%|▉| 22/24 [00:49<00:
# Compressing /encoder/layer.0/output/dense/MatMul:   3%| | 3/96 [00:05<02:54,  1.
# Compressing /encoder/layer.0/intermediate/dense/MatMul:  96%|▉| 23/24 [00:51<00:
# Compressing /encoder/layer.0/intermediate/dense/MatMul: 100%|█| 24/24 [00:53<00:
# Compressing /encoder/layer.1/attention/self/key/MatMul:   0%| | 0/24 [00:00<?, ?
# Compressing /encoder/layer.1/attention/self/key/MatMul:   4%| | 1/24 [00:02<00:5
# Compressing /encoder/layer.1/attention/self/key/MatMul:   8%| | 2/24 [00:04<00:4
# Compressing /encoder/layer.1/attention/self/key/MatMul:  12%|▏| 3/24 [00:06<00:4
# Compressing /encoder/layer.1/attention/self/key/MatMul:  17%|▏| 4/24 [00:08<00:4
# Compressing /encoder/layer.1/attention/self/key/MatMul:  21%|▏| 5/24 [00:10<00:3
# Compressing /encoder/layer.1/attention/self/key/MatMul:  25%|▎| 6/24 [00:12<00:3
# Compressing /encoder/layer.1/attention/self/key/MatMul:  29%|▎| 7/24 [00:13<00:3
# Compressing /encoder/layer.1/attention/self/key/MatMul:  33%|▎| 8/24 [00:15<00:3
# Compressing /encoder/layer.1/attention/self/key/MatMul:  42%|▍| 10/24 [00:19<00:
# Compressing /encoder/layer.1/attention/self/key/MatMul:  46%|▍| 11/24 [00:21<00:
# Compressing /encoder/layer.1/attention/self/key/MatMul:  50%|▌| 12/24 [00:23<00:
# Compressing /encoder/layer.1/attention/self/key/MatMul:  54%|▌| 13/24 [00:25<00:
# Compressing /encoder/layer.1/attention/self/key/MatMul:  58%|▌| 14/24 [00:27<00:
# Compressing /encoder/layer.1/attention/self/key/MatMul:  62%|▋| 15/24 [00:29<00:
# Compressing /encoder/layer.1/attention/self/key/MatMul:  67%|▋| 16/24 [00:31<00:
# Compressing /encoder/layer.1/attention/self/key/MatMul:  71%|▋| 17/24 [00:33<00:
# Compressing /encoder/layer.1/attention/self/key/MatMul:  75%|▊| 18/24 [00:36<00:
# Compressing /encoder/layer.0/output/dense/MatMul:  24%|▏| 23/96 [00:47<02:32,  2
# Compressing /encoder/layer.1/attention/self/key/MatMul:  79%|▊| 19/24 [00:38<00:
# Compressing /encoder/layer.1/attention/self/key/MatMul:  83%|▊| 20/24 [00:41<00:
# Compressing /encoder/layer.1/attention/self/key/MatMul:  88%|▉| 21/24 [00:43<00:
# Compressing /encoder/layer.1/attention/self/key/MatMul:  92%|▉| 22/24 [00:46<00:
# Compressing /encoder/layer.1/attention/self/key/MatMul:  96%|▉| 23/24 [00:48<00:
# Compressing /encoder/layer.1/attention/self/key/MatMul: 100%|█| 24/24 [00:50<00:
# Compressing /encoder/layer.1/attention/self/query/MatMul:   0%| | 0/24 [00:00<?,
# Compressing /encoder/layer.1/attention/self/query/MatMul:   4%| | 1/24 [00:02<00
# Compressing /encoder/layer.1/attention/self/query/MatMul:   8%| | 2/24 [00:04<00
# Compressing /encoder/layer.1/attention/self/query/MatMul:  12%|▏| 3/24 [00:07<00
# Compressing /encoder/layer.1/attention/self/query/MatMul:  17%|▏| 4/24 [00:09<00
# Compressing /encoder/layer.1/attention/self/query/MatMul:  21%|▏| 5/24 [00:11<00
# Compressing /encoder/layer.1/attention/self/query/MatMul:  25%|▎| 6/24 [00:13<00
# Compressing /encoder/layer.1/attention/self/query/MatMul:  29%|▎| 7/24 [00:15<00
# Compressing /encoder/layer.1/attention/self/query/MatMul:  33%|▎| 8/24 [00:17<00
# Compressing /encoder/layer.1/attention/self/query/MatMul:  38%|▍| 9/24 [00:19<00
# Compressing /encoder/layer.1/attention/self/query/MatMul:  42%|▍| 10/24 [00:21<0
# Compressing /encoder/layer.1/attention/self/query/MatMul:  46%|▍| 11/24 [00:24<0
# Compressing /encoder/layer.1/attention/self/query/MatMul:  50%|▌| 12/24 [00:26<0
# Compressing /encoder/layer.1/attention/self/query/MatMul:  54%|▌| 13/24 [00:28<0
# Compressing /encoder/layer.1/attention/self/query/MatMul:  58%|▌| 14/24 [00:30<0
# Compressing /encoder/layer.1/attention/self/query/MatMul:  62%|▋| 15/24 [00:32<0
# Compressing /encoder/layer.1/attention/self/query/MatMul:  67%|▋| 16/24 [00:34<0
# Compressing /encoder/layer.1/attention/self/query/MatMul:  71%|▋| 17/24 [00:36<0
# Compressing /encoder/layer.0/output/dense/MatMul:  49%|▍| 47/96 [01:38<01:40,  2
# Compressing /encoder/layer.1/attention/self/query/MatMul:  75%|▊| 18/24 [00:38<0
# Compressing /encoder/layer.1/attention/self/query/MatMul:  79%|▊| 19/24 [00:40<0
# Compressing /encoder/layer.1/attention/self/query/MatMul:  83%|▊| 20/24 [00:43<0
# Compressing /encoder/layer.1/attention/self/query/MatMul:  88%|▉| 21/24 [00:44<0
# Compressing /encoder/layer.1/attention/self/query/MatMul:  96%|▉| 23/24 [00:48<0
# Compressing /encoder/layer.0/output/dense/MatMul:  55%|▌| 53/96 [01:50<01:30,  2
# Compressing /encoder/layer.1/attention/self/query/MatMul: 100%|█| 24/24 [00:51<0
# Compressing /encoder/layer.1/attention/self/value/MatMul:   0%| | 0/24 [00:00<?,
# Compressing /encoder/layer.1/attention/self/value/MatMul:   4%| | 1/24 [00:02<00
# Compressing /encoder/layer.1/attention/self/value/MatMul:   8%| | 2/24 [00:04<00
# Compressing /encoder/layer.1/attention/self/value/MatMul:  12%|▏| 3/24 [00:06<00
# Compressing /encoder/layer.1/attention/self/value/MatMul:  17%|▏| 4/24 [00:08<00
# Compressing /encoder/layer.1/attention/self/value/MatMul:  21%|▏| 5/24 [00:10<00
# Compressing /encoder/layer.1/attention/self/value/MatMul:  25%|▎| 6/24 [00:12<00
# Compressing /encoder/layer.1/attention/self/value/MatMul:  29%|▎| 7/24 [00:14<00
# Compressing /encoder/layer.1/attention/self/value/MatMul:  33%|▎| 8/24 [00:16<00
# Compressing /encoder/layer.1/attention/self/value/MatMul:  38%|▍| 9/24 [00:18<00
# Compressing /encoder/layer.1/attention/self/value/MatMul:  42%|▍| 10/24 [00:20<0
# Compressing /encoder/layer.1/attention/self/value/MatMul:  46%|▍| 11/24 [00:22<0
# Compressing /encoder/layer.1/attention/self/value/MatMul:  50%|▌| 12/24 [00:24<0
# Compressing /encoder/layer.1/attention/self/value/MatMul:  54%|▌| 13/24 [00:26<0
# Compressing /encoder/layer.0/output/dense/MatMul:  71%|▋| 68/96 [02:20<00:58,  2
# Compressing /encoder/layer.1/attention/self/value/MatMul:  58%|▌| 14/24 [00:29<0
# Compressing /encoder/layer.1/attention/self/value/MatMul:  67%|▋| 16/24 [00:33<0
# Compressing /encoder/layer.1/attention/self/value/MatMul:  71%|▋| 17/24 [00:35<0
# Compressing /encoder/layer.1/attention/self/value/MatMul:  75%|▊| 18/24 [00:37<0
# Compressing /encoder/layer.1/attention/self/value/MatMul:  79%|▊| 19/24 [00:39<0
# Compressing /encoder/layer.1/attention/self/value/MatMul:  83%|▊| 20/24 [00:41<0
# Compressing /encoder/layer.1/attention/self/value/MatMul:  88%|▉| 21/24 [00:43<0
# Compressing /encoder/layer.0/output/dense/MatMul:  79%|▊| 76/96 [02:36<00:40,  2
# Compressing /encoder/layer.1/attention/self/value/MatMul:  92%|▉| 22/24 [00:46<0
# Compressing /encoder/layer.1/attention/self/value/MatMul:  96%|▉| 23/24 [00:48<0
# Compressing /encoder/layer.1/attention/self/value/MatMul: 100%|█| 24/24 [00:50<0
# Compressing /encoder/layer.1/attention/output/dense/MatMul:   0%| | 0/24 [00:00<
# Compressing /encoder/layer.1/attention/output/dense/MatMul:   4%| | 1/24 [00:01<
# Compressing /encoder/layer.1/attention/output/dense/MatMul:   8%| | 2/24 [00:03<
# Compressing /encoder/layer.1/attention/output/dense/MatMul:  12%|▏| 3/24 [00:05<
# Compressing /encoder/layer.1/attention/output/dense/MatMul:  17%|▏| 4/24 [00:08<
# Compressing /encoder/layer.1/attention/output/dense/MatMul:  21%|▏| 5/24 [00:10<
# Compressing /encoder/layer.1/attention/output/dense/MatMul:  25%|▎| 6/24 [00:12<
# Compressing /encoder/layer.1/attention/output/dense/MatMul:  29%|▎| 7/24 [00:14<
# Compressing /encoder/layer.1/attention/output/dense/MatMul:  33%|▎| 8/24 [00:16<
# Compressing /encoder/layer.1/attention/output/dense/MatMul:  38%|▍| 9/24 [00:18<
# Compressing /encoder/layer.1/attention/output/dense/MatMul:  42%|▍| 10/24 [00:20
# Compressing /encoder/layer.1/attention/output/dense/MatMul:  46%|▍| 11/24 [00:22
# Compressing /encoder/layer.1/attention/output/dense/MatMul:  50%|▌| 12/24 [00:24
# Compressing /encoder/layer.0/output/dense/MatMul:  96%|▉| 92/96 [03:08<00:07,  1
# Compressing /encoder/layer.1/attention/output/dense/MatMul:  58%|▌| 14/24 [00:28
# Compressing /encoder/layer.1/attention/output/dense/MatMul:  62%|▋| 15/24 [00:30
# Compressing /encoder/layer.1/attention/output/dense/MatMul:  67%|▋| 16/24 [00:32
# Compressing /encoder/layer.0/output/dense/MatMul: 100%|█| 96/96 [03:16<00:00,  2
#
# Compressing /encoder/layer.1/intermediate/dense/MatMul:   0%| | 0/24 [00:00<?, ?
# Compressing /encoder/layer.1/attention/output/dense/MatMul:  71%|▋| 17/24 [00:35
# Compressing /encoder/layer.1/attention/output/dense/MatMul:  75%|▊| 18/24 [00:37
# Compressing /encoder/layer.1/attention/output/dense/MatMul:  79%|▊| 19/24 [00:39
# Compressing /encoder/layer.1/attention/output/dense/MatMul:  88%|▉| 21/24 [00:43
# Compressing /encoder/layer.1/attention/output/dense/MatMul:  92%|▉| 22/24 [00:45
# Compressing /encoder/layer.1/attention/output/dense/MatMul:  96%|▉| 23/24 [00:47
# Compressing /encoder/layer.1/attention/output/dense/MatMul: 100%|█| 24/24 [00:49
#
# Compressing /encoder/layer.1/output/dense/MatMul:   0%|  | 0/96 [00:00<?, ?it/s]
# Compressing /encoder/layer.1/output/dense/MatMul:   1%| | 1/96 [00:02<03:17,  2.
# Compressing /encoder/layer.1/output/dense/MatMul:   2%| | 2/96 [00:04<03:27,  2.
# Compressing /encoder/layer.1/output/dense/MatMul:   3%| | 3/96 [00:06<03:25,  2.
# Compressing /encoder/layer.1/output/dense/MatMul:   4%| | 4/96 [00:08<03:25,  2.
# Compressing /encoder/layer.1/output/dense/MatMul:   5%| | 5/96 [00:11<03:25,  2.
# Compressing /encoder/layer.1/output/dense/MatMul:   6%| | 6/96 [00:13<03:14,  2.
# Compressing /encoder/layer.1/output/dense/MatMul:   8%| | 8/96 [00:16<02:52,  1.
# Compressing /encoder/layer.1/output/dense/MatMul:   9%| | 9/96 [00:18<02:49,  1.
# Compressing /encoder/layer.1/intermediate/dense/MatMul:  71%|▋| 17/24 [00:35<00:
# Compressing /encoder/layer.1/output/dense/MatMul:  10%| | 10/96 [00:20<02:57,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  11%| | 11/96 [00:23<03:09,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  12%|▏| 12/96 [00:25<03:05,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  14%|▏| 13/96 [00:27<02:54,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  16%|▏| 15/96 [00:31<02:40,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  17%|▏| 16/96 [00:33<02:39,  2
# Compressing /encoder/layer.1/intermediate/dense/MatMul: 100%|█| 24/24 [00:50<00:
#
# Compressing /encoder/layer.1/output/dense/MatMul:  18%|▏| 17/96 [00:35<02:45,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  19%|▏| 18/96 [00:37<02:42,  2
# Compressing /encoder/layer.2/attention/self/key/MatMul:   8%| | 2/24 [00:03<00:4
# Compressing /encoder/layer.1/output/dense/MatMul:  20%|▏| 19/96 [00:40<02:46,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  21%|▏| 20/96 [00:41<02:37,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  23%|▏| 22/96 [00:45<02:27,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  24%|▏| 23/96 [00:47<02:24,  1
# Compressing /encoder/layer.2/attention/self/key/MatMul:  29%|▎| 7/24 [00:13<00:3
# Compressing /encoder/layer.1/output/dense/MatMul:  25%|▎| 24/96 [00:49<02:25,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  26%|▎| 25/96 [00:52<02:29,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  27%|▎| 26/96 [00:54<02:25,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  28%|▎| 27/96 [00:56<02:27,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  29%|▎| 28/96 [00:58<02:24,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  30%|▎| 29/96 [01:00<02:18,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  32%|▎| 31/96 [01:04<02:09,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  33%|▎| 32/96 [01:06<02:06,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  34%|▎| 33/96 [01:08<02:03,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  35%|▎| 34/96 [01:10<02:00,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  36%|▎| 35/96 [01:11<01:56,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  38%|▍| 36/96 [01:13<01:53,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  39%|▍| 37/96 [01:15<01:53,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  40%|▍| 38/96 [01:17<01:54,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  41%|▍| 39/96 [01:19<01:53,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  42%|▍| 40/96 [01:21<01:51,  1
# Compressing /encoder/layer.2/attention/self/key/MatMul: 100%|█| 24/24 [00:49<00:
#
# Compressing /encoder/layer.1/output/dense/MatMul:  44%|▍| 42/96 [01:25<01:45,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  45%|▍| 43/96 [01:27<01:42,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  46%|▍| 44/96 [01:29<01:41,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  47%|▍| 45/96 [01:31<01:38,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  48%|▍| 46/96 [01:33<01:35,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  49%|▍| 47/96 [01:36<01:48,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  50%|▌| 48/96 [01:38<01:48,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  52%|▌| 50/96 [01:42<01:36,  2
# Compressing /encoder/layer.2/attention/self/query/MatMul:  33%|▎| 8/24 [00:18<00
# Compressing /encoder/layer.1/output/dense/MatMul:  53%|▌| 51/96 [01:44<01:35,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  55%|▌| 53/96 [01:48<01:28,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  56%|▌| 54/96 [01:50<01:23,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  57%|▌| 55/96 [01:52<01:18,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  59%|▌| 57/96 [01:55<01:10,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  60%|▌| 58/96 [01:57<01:09,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  61%|▌| 59/96 [01:59<01:07,  1
# Compressing /encoder/layer.2/attention/self/query/MatMul:  67%|▋| 16/24 [00:35<0
# Compressing /encoder/layer.1/output/dense/MatMul:  62%|▋| 60/96 [02:01<01:07,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  64%|▋| 61/96 [02:03<01:06,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  66%|▋| 63/96 [02:07<01:02,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  67%|▋| 64/96 [02:09<01:00,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  68%|▋| 65/96 [02:10<00:58,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  69%|▋| 66/96 [02:13<01:00,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  70%|▋| 67/96 [02:15<01:01,  2
# Compressing /encoder/layer.2/attention/self/query/MatMul: 100%|█| 24/24 [00:52<0
#
# Compressing /encoder/layer.1/output/dense/MatMul:  71%|▋| 68/96 [02:17<01:00,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  72%|▋| 69/96 [02:19<00:57,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  73%|▋| 70/96 [02:21<00:53,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  74%|▋| 71/96 [02:23<00:51,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  76%|▊| 73/96 [02:27<00:46,  2
# Compressing /encoder/layer.1/output/dense/MatMul:  77%|▊| 74/96 [02:29<00:43,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  78%|▊| 75/96 [02:31<00:40,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  79%|▊| 76/96 [02:33<00:37,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  80%|▊| 77/96 [02:35<00:35,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  82%|▊| 79/96 [02:39<00:32,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  83%|▊| 80/96 [02:41<00:30,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  84%|▊| 81/96 [02:42<00:28,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  85%|▊| 82/96 [02:44<00:26,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  86%|▊| 83/96 [02:46<00:24,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  88%|▉| 84/96 [02:48<00:23,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  89%|▉| 85/96 [02:50<00:21,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  90%|▉| 86/96 [02:52<00:19,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  91%|▉| 87/96 [02:54<00:17,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  93%|▉| 89/96 [02:58<00:13,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  94%|▉| 90/96 [03:00<00:11,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  95%|▉| 91/96 [03:02<00:09,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  96%|▉| 92/96 [03:03<00:07,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  97%|▉| 93/96 [03:05<00:05,  1
# Compressing /encoder/layer.1/output/dense/MatMul:  98%|▉| 94/96 [03:07<00:03,  1
# Compressing /encoder/layer.2/attention/self/value/MatMul: 100%|█| 24/24 [00:52<0
#
# Compressing /encoder/layer.1/output/dense/MatMul:  99%|▉| 95/96 [03:09<00:01,  1
# Compressing /encoder/layer.1/output/dense/MatMul: 100%|█| 96/96 [03:11<00:00,  2
# Compressing /encoder/layer.2/intermediate/dense/MatMul:   0%| | 0/24 [00:00<?, ?
# Compressing /encoder/layer.2/intermediate/dense/MatMul:   4%| | 1/24 [00:02<00:4
# Compressing /encoder/layer.2/intermediate/dense/MatMul:   8%| | 2/24 [00:04<00:4
# Compressing /encoder/layer.2/intermediate/dense/MatMul:  17%|▏| 4/24 [00:07<00:3
# Compressing /encoder/layer.2/intermediate/dense/MatMul:  21%|▏| 5/24 [00:09<00:3
# Compressing /encoder/layer.2/intermediate/dense/MatMul:  25%|▎| 6/24 [00:11<00:3
# Compressing /encoder/layer.2/intermediate/dense/MatMul:  29%|▎| 7/24 [00:13<00:3
# Compressing /encoder/layer.2/intermediate/dense/MatMul:  33%|▎| 8/24 [00:15<00:3
# Compressing /encoder/layer.2/intermediate/dense/MatMul:  38%|▍| 9/24 [00:17<00:2
# Compressing /encoder/layer.2/intermediate/dense/MatMul:  42%|▍| 10/24 [00:19<00:
# Compressing /encoder/layer.2/intermediate/dense/MatMul:  46%|▍| 11/24 [00:21<00:
# Compressing /encoder/layer.2/intermediate/dense/MatMul:  50%|▌| 12/24 [00:23<00:
# Compressing /encoder/layer.2/intermediate/dense/MatMul:  58%|▌| 14/24 [00:27<00:
# Compressing /encoder/layer.2/intermediate/dense/MatMul:  62%|▋| 15/24 [00:29<00:
# Compressing /encoder/layer.2/intermediate/dense/MatMul:  67%|▋| 16/24 [00:31<00:
# Compressing /encoder/layer.2/intermediate/dense/MatMul:  71%|▋| 17/24 [00:33<00:
# Compressing /encoder/layer.2/intermediate/dense/MatMul:  75%|▊| 18/24 [00:34<00:
# Compressing /encoder/layer.2/intermediate/dense/MatMul:  79%|▊| 19/24 [00:36<00:
# Compressing /encoder/layer.2/intermediate/dense/MatMul:  83%|▊| 20/24 [00:38<00:
# Compressing /encoder/layer.2/intermediate/dense/MatMul:  88%|▉| 21/24 [00:40<00:
# Compressing /encoder/layer.2/intermediate/dense/MatMul:  96%|▉| 23/24 [00:44<00:
# Compressing /encoder/layer.2/intermediate/dense/MatMul: 100%|█| 24/24 [00:46<00:
# Compressing /encoder/layer.2/output/dense/MatMul:   0%|  | 0/96 [00:00<?, ?it/s]
# Compressing /encoder/layer.2/output/dense/MatMul:   1%| | 1/96 [00:01<03:00,  1.
# Compressing /encoder/layer.2/attention/output/dense/MatMul: 100%|█| 24/24 [00:51
#
# Compressing /encoder/layer.2/output/dense/MatMul:   2%| | 2/96 [00:03<03:02,  1.
# Compressing /encoder/layer.2/output/dense/MatMul:   3%| | 3/96 [00:05<02:58,  1.
# Compressing /encoder/layer.2/output/dense/MatMul:   4%| | 4/96 [00:07<03:05,  2.
# Compressing /encoder/layer.2/output/dense/MatMul:   5%| | 5/96 [00:10<03:07,  2.
# Compressing /encoder/layer.2/output/dense/MatMul:   6%| | 6/96 [00:12<03:09,  2.
# Compressing /encoder/layer.2/output/dense/MatMul:   7%| | 7/96 [00:14<03:02,  2.
# Compressing /encoder/layer.2/output/dense/MatMul:   9%| | 9/96 [00:17<02:49,  1.
# Compressing /encoder/layer.2/output/dense/MatMul:  10%| | 10/96 [00:19<02:46,  1
# Compressing /encoder/layer.3/attention/self/key/MatMul:  33%|▎| 8/24 [00:17<00:3
# Compressing /encoder/layer.2/output/dense/MatMul:  11%| | 11/96 [00:22<02:54,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  14%|▏| 13/96 [00:26<03:03,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  15%|▏| 14/96 [00:28<02:55,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  16%|▏| 15/96 [00:30<02:50,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  17%|▏| 16/96 [00:33<02:50,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  18%|▏| 17/96 [00:35<02:53,  2
# Compressing /encoder/layer.3/attention/self/key/MatMul:  62%|▋| 15/24 [00:33<00:
# Compressing /encoder/layer.2/output/dense/MatMul:  19%|▏| 18/96 [00:37<02:57,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  20%|▏| 19/96 [00:40<02:53,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  21%|▏| 20/96 [00:42<02:44,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  22%|▏| 21/96 [00:43<02:36,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  23%|▏| 22/96 [00:45<02:32,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  24%|▏| 23/96 [00:48<02:31,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  25%|▎| 24/96 [00:49<02:24,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  27%|▎| 26/96 [00:53<02:16,  1
# Compressing /encoder/layer.3/attention/self/key/MatMul: 100%|█| 24/24 [00:51<00:
#
# Compressing /encoder/layer.2/output/dense/MatMul:  28%|▎| 27/96 [00:55<02:16,  1
# Compressing /encoder/layer.2/output/dense/MatMul:  29%|▎| 28/96 [00:57<02:13,  1
# Compressing /encoder/layer.2/output/dense/MatMul:  30%|▎| 29/96 [00:59<02:10,  1
# Compressing /encoder/layer.2/output/dense/MatMul:  31%|▎| 30/96 [01:01<02:07,  1
# Compressing /encoder/layer.2/output/dense/MatMul:  32%|▎| 31/96 [01:03<02:07,  1
# Compressing /encoder/layer.2/output/dense/MatMul:  33%|▎| 32/96 [01:05<02:07,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  34%|▎| 33/96 [01:07<02:03,  1
# Compressing /encoder/layer.2/output/dense/MatMul:  35%|▎| 34/96 [01:09<02:00,  1
# Compressing /encoder/layer.2/output/dense/MatMul:  36%|▎| 35/96 [01:11<02:01,  1
# Compressing /encoder/layer.2/output/dense/MatMul:  38%|▍| 36/96 [01:13<02:00,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  39%|▍| 37/96 [01:15<02:04,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  40%|▍| 38/96 [01:18<02:05,  2
# Compressing /encoder/layer.3/attention/self/query/MatMul:  50%|▌| 12/24 [00:24<0
# Compressing /encoder/layer.2/output/dense/MatMul:  41%|▍| 39/96 [01:20<02:03,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  42%|▍| 40/96 [01:22<02:00,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  44%|▍| 42/96 [01:26<01:52,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  45%|▍| 43/96 [01:28<01:48,  2
# Compressing /encoder/layer.3/attention/self/query/MatMul:  71%|▋| 17/24 [00:34<0
# Compressing /encoder/layer.2/output/dense/MatMul:  46%|▍| 44/96 [01:31<01:58,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  47%|▍| 45/96 [01:34<02:06,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  48%|▍| 46/96 [01:36<01:58,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  49%|▍| 47/96 [01:38<01:47,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  50%|▌| 48/96 [01:40<01:42,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  51%|▌| 49/96 [01:42<01:39,  2
# Compressing /encoder/layer.3/attention/self/query/MatMul: 100%|█| 24/24 [00:49<0
#
# Compressing /encoder/layer.2/output/dense/MatMul:  52%|▌| 50/96 [01:44<01:40,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  53%|▌| 51/96 [01:46<01:37,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  54%|▌| 52/96 [01:48<01:36,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  55%|▌| 53/96 [01:51<01:36,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  56%|▌| 54/96 [01:53<01:34,  2
# Compressing /encoder/layer.3/attention/self/value/MatMul:  21%|▏| 5/24 [00:09<00
# Compressing /encoder/layer.2/output/dense/MatMul:  57%|▌| 55/96 [01:55<01:32,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  58%|▌| 56/96 [01:58<01:31,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  59%|▌| 57/96 [02:00<01:31,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  60%|▌| 58/96 [02:03<01:30,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  61%|▌| 59/96 [02:05<01:25,  2
# Compressing /encoder/layer.3/attention/self/value/MatMul:  46%|▍| 11/24 [00:21<0
# Compressing /encoder/layer.2/output/dense/MatMul:  62%|▋| 60/96 [02:07<01:22,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  64%|▋| 61/96 [02:09<01:19,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  65%|▋| 62/96 [02:12<01:18,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  66%|▋| 63/96 [02:14<01:13,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  67%|▋| 64/96 [02:16<01:09,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  68%|▋| 65/96 [02:18<01:04,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  69%|▋| 66/96 [02:20<01:03,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  70%|▋| 67/96 [02:22<01:03,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  72%|▋| 69/96 [02:26<00:53,  1
# Compressing /encoder/layer.2/output/dense/MatMul:  73%|▋| 70/96 [02:27<00:50,  1
# Compressing /encoder/layer.2/output/dense/MatMul:  74%|▋| 71/96 [02:30<00:49,  1
# Compressing /encoder/layer.2/output/dense/MatMul:  75%|▊| 72/96 [02:32<00:50,  2
# Compressing /encoder/layer.3/attention/self/value/MatMul: 100%|█| 24/24 [00:48<0
#
# Compressing /encoder/layer.2/output/dense/MatMul:  76%|▊| 73/96 [02:34<00:49,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  77%|▊| 74/96 [02:37<00:48,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  78%|▊| 75/96 [02:39<00:48,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  79%|▊| 76/96 [02:41<00:44,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  80%|▊| 77/96 [02:43<00:42,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  81%|▊| 78/96 [02:45<00:38,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  82%|▊| 79/96 [02:48<00:37,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  83%|▊| 80/96 [02:50<00:36,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  84%|▊| 81/96 [02:52<00:31,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  85%|▊| 82/96 [02:54<00:29,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  86%|▊| 83/96 [02:57<00:30,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  88%|▉| 84/96 [03:00<00:30,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  89%|▉| 85/96 [03:02<00:27,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  90%|▉| 86/96 [03:05<00:24,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  91%|▉| 87/96 [03:07<00:21,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  93%|▉| 89/96 [03:11<00:15,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  94%|▉| 90/96 [03:13<00:13,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  95%|▉| 91/96 [03:16<00:11,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  96%|▉| 92/96 [03:18<00:09,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  97%|▉| 93/96 [03:20<00:06,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  98%|▉| 94/96 [03:22<00:04,  2
# Compressing /encoder/layer.2/output/dense/MatMul:  99%|▉| 95/96 [03:25<00:02,  2
# Compressing /encoder/layer.2/output/dense/MatMul: 100%|█| 96/96 [03:27<00:00,  2
# Compressing /encoder/layer.3/intermediate/dense/MatMul:   0%| | 0/24 [00:00<?, ?
# Compressing /encoder/layer.3/intermediate/dense/MatMul:   4%| | 1/24 [00:02<00:5
# Compressing /encoder/layer.3/attention/output/dense/MatMul: 100%|█| 24/24 [00:59
# Compressing /encoder/layer.3/intermediate/dense/MatMul:   8%| | 2/24 [00:04<00:5
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  12%|▏| 3/24 [00:06<00:4
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  17%|▏| 4/24 [00:08<00:4
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  21%|▏| 5/24 [00:11<00:4
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  25%|▎| 6/24 [00:13<00:4
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  29%|▎| 7/24 [00:15<00:3
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  33%|▎| 8/24 [00:18<00:3
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  38%|▍| 9/24 [00:20<00:3
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  42%|▍| 10/24 [00:22<00:
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  50%|▌| 12/24 [00:27<00:
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  54%|▌| 13/24 [00:29<00:
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  58%|▌| 14/24 [00:31<00:
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  62%|▋| 15/24 [00:34<00:
# Compressing /encoder/layer.3/output/dense/MatMul:  12%|▏| 12/96 [00:29<03:22,  2
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  71%|▋| 17/24 [00:38<00:
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  75%|▊| 18/24 [00:40<00:
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  79%|▊| 19/24 [00:43<00:
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  83%|▊| 20/24 [00:45<00:
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  88%|▉| 21/24 [00:48<00:
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  92%|▉| 22/24 [00:50<00:
# Compressing /encoder/layer.3/intermediate/dense/MatMul:  96%|▉| 23/24 [00:52<00:
# Compressing /encoder/layer.3/intermediate/dense/MatMul: 100%|█| 24/24 [00:55<00:
# Compressing /encoder/layer.4/attention/self/key/MatMul:   0%| | 0/24 [00:00<?, ?
# Compressing /encoder/layer.4/attention/self/key/MatMul:   4%| | 1/24 [00:02<00:4
# Compressing /encoder/layer.4/attention/self/key/MatMul:   8%| | 2/24 [00:04<00:4
# Compressing /encoder/layer.4/attention/self/key/MatMul:  12%|▏| 3/24 [00:06<00:4
# Compressing /encoder/layer.4/attention/self/key/MatMul:  17%|▏| 4/24 [00:08<00:4
# Compressing /encoder/layer.4/attention/self/key/MatMul:  21%|▏| 5/24 [00:11<00:4
# Compressing /encoder/layer.4/attention/self/key/MatMul:  25%|▎| 6/24 [00:13<00:4
# Compressing /encoder/layer.4/attention/self/key/MatMul:  29%|▎| 7/24 [00:15<00:3
# Compressing /encoder/layer.4/attention/self/key/MatMul:  33%|▎| 8/24 [00:18<00:3
# Compressing /encoder/layer.4/attention/self/key/MatMul:  38%|▍| 9/24 [00:21<00:3
# Compressing /encoder/layer.4/attention/self/key/MatMul:  42%|▍| 10/24 [00:23<00:
# Compressing /encoder/layer.4/attention/self/key/MatMul:  46%|▍| 11/24 [00:25<00:
# Compressing /encoder/layer.4/attention/self/key/MatMul:  50%|▌| 12/24 [00:28<00:
# Compressing /encoder/layer.4/attention/self/key/MatMul:  54%|▌| 13/24 [00:30<00:
# Compressing /encoder/layer.4/attention/self/key/MatMul:  62%|▋| 15/24 [00:35<00:
# Compressing /encoder/layer.4/attention/self/key/MatMul:  67%|▋| 16/24 [00:37<00:
# Compressing /encoder/layer.4/attention/self/key/MatMul:  71%|▋| 17/24 [00:39<00:
# Compressing /encoder/layer.4/attention/self/key/MatMul:  75%|▊| 18/24 [00:42<00:
# Compressing /encoder/layer.3/output/dense/MatMul:  40%|▍| 38/96 [01:32<02:18,  2
# Compressing /encoder/layer.4/attention/self/key/MatMul:  79%|▊| 19/24 [00:44<00:
# Compressing /encoder/layer.4/attention/self/key/MatMul:  83%|▊| 20/24 [00:47<00:
# Compressing /encoder/layer.4/attention/self/key/MatMul:  88%|▉| 21/24 [00:49<00:
# Compressing /encoder/layer.4/attention/self/key/MatMul:  92%|▉| 22/24 [00:52<00:
# Compressing /encoder/layer.4/attention/self/key/MatMul:  96%|▉| 23/24 [00:54<00:
# Compressing /encoder/layer.4/attention/self/key/MatMul: 100%|█| 24/24 [00:57<00:
# Compressing /encoder/layer.4/attention/self/query/MatMul:   0%| | 0/24 [00:00<?,
# Compressing /encoder/layer.4/attention/self/query/MatMul:   4%| | 1/24 [00:02<00
# Compressing /encoder/layer.4/attention/self/query/MatMul:   8%| | 2/24 [00:04<00
# Compressing /encoder/layer.4/attention/self/query/MatMul:  12%|▏| 3/24 [00:06<00
# Compressing /encoder/layer.4/attention/self/query/MatMul:  17%|▏| 4/24 [00:09<00
# Compressing /encoder/layer.4/attention/self/query/MatMul:  21%|▏| 5/24 [00:11<00
# Compressing /encoder/layer.4/attention/self/query/MatMul:  25%|▎| 6/24 [00:13<00
# Compressing /encoder/layer.4/attention/self/query/MatMul:  29%|▎| 7/24 [00:16<00
# Compressing /encoder/layer.4/attention/self/query/MatMul:  33%|▎| 8/24 [00:19<00
# Compressing /encoder/layer.4/attention/self/query/MatMul:  38%|▍| 9/24 [00:21<00
# Compressing /encoder/layer.4/attention/self/query/MatMul:  42%|▍| 10/24 [00:24<0
# Compressing /encoder/layer.4/attention/self/query/MatMul:  46%|▍| 11/24 [00:26<0
# Compressing /encoder/layer.4/attention/self/query/MatMul:  50%|▌| 12/24 [00:28<0
# Compressing /encoder/layer.4/attention/self/query/MatMul:  54%|▌| 13/24 [00:31<0
# Compressing /encoder/layer.4/attention/self/query/MatMul:  58%|▌| 14/24 [00:33<0
# Compressing /encoder/layer.3/output/dense/MatMul:  61%|▌| 59/96 [02:23<01:28,  2
# Compressing /encoder/layer.4/attention/self/query/MatMul:  62%|▋| 15/24 [00:37<0
# Compressing /encoder/layer.4/attention/self/query/MatMul:  71%|▋| 17/24 [00:41<0
# Compressing /encoder/layer.4/attention/self/query/MatMul:  75%|▊| 18/24 [00:43<0
# Compressing /encoder/layer.4/attention/self/query/MatMul:  79%|▊| 19/24 [00:46<0
# Compressing /encoder/layer.4/attention/self/query/MatMul:  83%|▊| 20/24 [00:48<0
# Compressing /encoder/layer.4/attention/self/query/MatMul:  88%|▉| 21/24 [00:51<0
# Compressing /encoder/layer.4/attention/self/query/MatMul:  92%|▉| 22/24 [00:53<0
# Compressing /encoder/layer.3/output/dense/MatMul:  70%|▋| 67/96 [02:42<01:07,  2
# Compressing /encoder/layer.4/attention/self/query/MatMul: 100%|█| 24/24 [00:58<0
# Compressing /encoder/layer.4/attention/self/value/MatMul:   0%| | 0/24 [00:00<?,
# Compressing /encoder/layer.4/attention/self/value/MatMul:   4%| | 1/24 [00:02<00
# Compressing /encoder/layer.4/attention/self/value/MatMul:   8%| | 2/24 [00:04<00
# Compressing /encoder/layer.3/output/dense/MatMul:  74%|▋| 71/96 [02:52<01:03,  2
# Compressing /encoder/layer.4/attention/self/value/MatMul:  17%|▏| 4/24 [00:09<00
# Compressing /encoder/layer.4/attention/self/value/MatMul:  21%|▏| 5/24 [00:11<00
# Compressing /encoder/layer.4/attention/self/value/MatMul:  25%|▎| 6/24 [00:14<00
# Compressing /encoder/layer.3/output/dense/MatMul:  78%|▊| 75/96 [03:01<00:48,  2
# Compressing /encoder/layer.4/attention/self/value/MatMul:  29%|▎| 7/24 [00:16<00
# Compressing /encoder/layer.4/attention/self/value/MatMul:  33%|▎| 8/24 [00:19<00
# Compressing /encoder/layer.4/attention/self/value/MatMul:  38%|▍| 9/24 [00:21<00
# Compressing /encoder/layer.4/attention/self/value/MatMul:  42%|▍| 10/24 [00:23<0
# Compressing /encoder/layer.4/attention/self/value/MatMul:  46%|▍| 11/24 [00:25<0
# Compressing /encoder/layer.4/attention/self/value/MatMul:  50%|▌| 12/24 [00:27<0
# Compressing /encoder/layer.4/attention/self/value/MatMul:  58%|▌| 14/24 [00:31<0
# Compressing /encoder/layer.3/output/dense/MatMul:  86%|▊| 83/96 [03:18<00:28,  2
# Compressing /encoder/layer.4/attention/self/value/MatMul:  62%|▋| 15/24 [00:34<0
# Compressing /encoder/layer.4/attention/self/value/MatMul:  67%|▋| 16/24 [00:36<0
# Compressing /encoder/layer.4/attention/self/value/MatMul:  71%|▋| 17/24 [00:39<0
# Compressing /encoder/layer.4/attention/self/value/MatMul:  75%|▊| 18/24 [00:41<0
# Compressing /encoder/layer.4/attention/self/value/MatMul:  79%|▊| 19/24 [00:43<0
# Compressing /encoder/layer.4/attention/self/value/MatMul:  83%|▊| 20/24 [00:45<0
# Compressing /encoder/layer.4/attention/self/value/MatMul:  88%|▉| 21/24 [00:47<0
# Compressing /encoder/layer.3/output/dense/MatMul:  95%|▉| 91/96 [03:35<00:09,  1
# Compressing /encoder/layer.4/attention/self/value/MatMul:  92%|▉| 22/24 [00:50<0
# Compressing /encoder/layer.4/attention/self/value/MatMul:  96%|▉| 23/24 [00:52<0
# Compressing /encoder/layer.4/attention/self/value/MatMul: 100%|█| 24/24 [00:54<0
# Compressing /encoder/layer.4/attention/output/dense/MatMul:   0%| | 0/24 [00:00<
# Compressing /encoder/layer.4/attention/output/dense/MatMul:   4%| | 1/24 [00:02<
# Compressing /encoder/layer.3/output/dense/MatMul: 100%|█| 96/96 [03:46<00:00,  2
# Compressing /encoder/layer.4/attention/output/dense/MatMul:   8%| | 2/24 [00:03<
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  12%|▏| 3/24 [00:06<
# Compressing /encoder/layer.4/intermediate/dense/MatMul:   4%| | 1/24 [00:02<00:4
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  17%|▏| 4/24 [00:08<
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  21%|▏| 5/24 [00:10<
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  29%|▎| 7/24 [00:14<
# Compressing /encoder/layer.4/intermediate/dense/MatMul:  21%|▏| 5/24 [00:10<00:4
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  33%|▎| 8/24 [00:16<
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  38%|▍| 9/24 [00:19<
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  42%|▍| 10/24 [00:21
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  46%|▍| 11/24 [00:23
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  50%|▌| 12/24 [00:25
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  54%|▌| 13/24 [00:27
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  58%|▌| 14/24 [00:29
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  62%|▋| 15/24 [00:31
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  67%|▋| 16/24 [00:33
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  71%|▋| 17/24 [00:36
# Compressing /encoder/layer.4/intermediate/dense/MatMul:  67%|▋| 16/24 [00:32<00:
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  79%|▊| 19/24 [00:41
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  83%|▊| 20/24 [00:42
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  88%|▉| 21/24 [00:44
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  92%|▉| 22/24 [00:47
# Compressing /encoder/layer.4/attention/output/dense/MatMul:  96%|▉| 23/24 [00:49
# Compressing /encoder/layer.4/intermediate/dense/MatMul:  92%|▉| 22/24 [00:44<00:
# Compressing /encoder/layer.4/attention/output/dense/MatMul: 100%|█| 24/24 [00:51
# Compressing /encoder/layer.4/output/dense/MatMul:   0%|  | 0/96 [00:00<?, ?it/s]
# Compressing /encoder/layer.4/intermediate/dense/MatMul: 100%|█| 24/24 [00:49<00:
#
# Compressing /encoder/layer.4/output/dense/MatMul:   1%| | 1/96 [00:02<03:35,  2.
# Compressing /encoder/layer.4/output/dense/MatMul:   2%| | 2/96 [00:04<03:38,  2.
# Compressing /encoder/layer.4/output/dense/MatMul:   3%| | 3/96 [00:06<03:31,  2.
# Compressing /encoder/layer.4/output/dense/MatMul:   4%| | 4/96 [00:08<03:20,  2.
# Compressing /encoder/layer.4/output/dense/MatMul:   5%| | 5/96 [00:10<03:14,  2.
# Compressing /encoder/layer.4/output/dense/MatMul:   6%| | 6/96 [00:13<03:17,  2.
# Compressing /encoder/layer.4/output/dense/MatMul:   7%| | 7/96 [00:15<03:20,  2.
# Compressing /encoder/layer.4/output/dense/MatMul:   8%| | 8/96 [00:17<03:17,  2.
# Compressing /encoder/layer.4/output/dense/MatMul:   9%| | 9/96 [00:19<03:06,  2.
# Compressing /encoder/layer.4/output/dense/MatMul:  10%| | 10/96 [00:21<03:04,  2
# Compressing /encoder/layer.4/output/dense/MatMul:  11%| | 11/96 [00:24<03:12,  2
# Compressing /encoder/layer.4/output/dense/MatMul:  12%|▏| 12/96 [00:26<03:09,  2
# Compressing /encoder/layer.4/output/dense/MatMul:  14%|▏| 13/96 [00:29<03:20,  2
# Compressing /encoder/layer.4/output/dense/MatMul:  15%|▏| 14/96 [00:31<03:20,  2
# Compressing /encoder/layer.5/attention/self/key/MatMul:  58%|▌| 14/24 [00:30<00:
# Compressing /encoder/layer.4/output/dense/MatMul:  16%|▏| 15/96 [00:33<03:07,  2
# Compressing /encoder/layer.4/output/dense/MatMul:  17%|▏| 16/96 [00:35<02:56,  2
# Compressing /encoder/layer.4/output/dense/MatMul:  19%|▏| 18/96 [00:39<02:40,  2
# Compressing /encoder/layer.4/output/dense/MatMul:  20%|▏| 19/96 [00:42<02:43,  2
# ...
# Compressing /encoder/layer.9/output/dense/MatMul:  98%|▉| 94/96 [03:35<00:05,  2
# Compressing /encoder/layer.9/output/dense/MatMul:  99%|▉| 95/96 [03:37<00:02,  2
# Compressing /encoder/layer.9/output/dense/MatMul: 100%|█| 96/96 [03:39<00:00,  2
# Compressing /encoder/layer.10/intermediate/dense/MatMul:   0%| | 0/24 [00:00<?,
# Compressing /encoder/layer.10/intermediate/dense/MatMul:   4%| | 1/24 [00:02<00:
# Compressing /encoder/layer.10/intermediate/dense/MatMul:  12%|▏| 3/24 [00:05<00:
# Compressing /encoder/layer.10/intermediate/dense/MatMul:  17%|▏| 4/24 [00:07<00:
# Compressing /encoder/layer.10/intermediate/dense/MatMul:  21%|▏| 5/24 [00:09<00:
# Compressing /encoder/layer.10/intermediate/dense/MatMul:  25%|▎| 6/24 [00:11<00:
# Compressing /encoder/layer.10/intermediate/dense/MatMul:  29%|▎| 7/24 [00:14<00:
# Compressing /encoder/layer.10/intermediate/dense/MatMul:  33%|▎| 8/24 [00:16<00:
# Compressing /encoder/layer.10/intermediate/dense/MatMul:  38%|▍| 9/24 [00:18<00:
# Compressing /encoder/layer.10/intermediate/dense/MatMul:  42%|▍| 10/24 [00:20<00
# Compressing /encoder/layer.10/attention/output/dense/MatMul: 100%|█| 24/24 [00:4
#
# Compressing /encoder/layer.10/intermediate/dense/MatMul:  46%|▍| 11/24 [00:22<00
# Compressing /encoder/layer.10/intermediate/dense/MatMul:  50%|▌| 12/24 [00:24<00
# Compressing /encoder/layer.10/intermediate/dense/MatMul:  54%|▌| 13/24 [00:26<00
# Compressing /encoder/layer.10/intermediate/dense/MatMul:  58%|▌| 14/24 [00:29<00
# Compressing /encoder/layer.10/intermediate/dense/MatMul:  62%|▋| 15/24 [00:31<00
# Compressing /encoder/layer.10/intermediate/dense/MatMul:  67%|▋| 16/24 [00:32<00
# Compressing /encoder/layer.10/intermediate/dense/MatMul:  71%|▋| 17/24 [00:34<00
# Compressing /encoder/layer.10/intermediate/dense/MatMul:  75%|▊| 18/24 [00:36<00
# Compressing /encoder/layer.10/intermediate/dense/MatMul:  79%|▊| 19/24 [00:38<00
# Compressing /encoder/layer.10/intermediate/dense/MatMul:  88%|▉| 21/24 [00:43<00
# Compressing /encoder/layer.10/output/dense/MatMul:  10%| | 10/96 [00:21<03:10,
# Compressing /encoder/layer.10/intermediate/dense/MatMul:  92%|▉| 22/24 [00:45<00
# Compressing /encoder/layer.10/intermediate/dense/MatMul: 100%|█| 24/24 [00:49<00
# Compressing /encoder/layer.11/attention/self/key/MatMul:   0%| | 0/24 [00:00<?,
# Compressing /encoder/layer.11/attention/self/key/MatMul:   4%| | 1/24 [00:01<00:
# Compressing /encoder/layer.11/attention/self/key/MatMul:   8%| | 2/24 [00:03<00:
# Compressing /encoder/layer.11/attention/self/key/MatMul:  12%|▏| 3/24 [00:06<00:
# Compressing /encoder/layer.11/attention/self/key/MatMul:  17%|▏| 4/24 [00:08<00:
# Compressing /encoder/layer.11/attention/self/key/MatMul:  21%|▏| 5/24 [00:10<00:
# Compressing /encoder/layer.11/attention/self/key/MatMul:  25%|▎| 6/24 [00:12<00:
# Compressing /encoder/layer.11/attention/self/key/MatMul:  29%|▎| 7/24 [00:14<00:
# Compressing /encoder/layer.11/attention/self/key/MatMul:  38%|▍| 9/24 [00:18<00:
# Compressing /encoder/layer.10/output/dense/MatMul:  22%|▏| 21/96 [00:45<02:51,
# Compressing /encoder/layer.11/attention/self/key/MatMul:  42%|▍| 10/24 [00:20<00
# Compressing /encoder/layer.11/attention/self/key/MatMul:  46%|▍| 11/24 [00:22<00
# Compressing /encoder/layer.11/attention/self/key/MatMul:  50%|▌| 12/24 [00:24<00
# Compressing /encoder/layer.11/attention/self/key/MatMul:  54%|▌| 13/24 [00:27<00
# Compressing /encoder/layer.11/attention/self/key/MatMul:  62%|▋| 15/24 [00:30<00
# Compressing /encoder/layer.11/attention/self/key/MatMul:  67%|▋| 16/24 [00:32<00
# Compressing /encoder/layer.11/attention/self/key/MatMul:  71%|▋| 17/24 [00:35<00
# Compressing /encoder/layer.10/output/dense/MatMul:  30%|▎| 29/96 [01:02<02:25,
# Compressing /encoder/layer.11/attention/self/key/MatMul:  79%|▊| 19/24 [00:39<00
# Compressing /encoder/layer.11/attention/self/key/MatMul:  83%|▊| 20/24 [00:41<00
# Compressing /encoder/layer.11/attention/self/key/MatMul:  88%|▉| 21/24 [00:43<00
# Compressing /encoder/layer.11/attention/self/key/MatMul:  92%|▉| 22/24 [00:45<00
# Compressing /encoder/layer.11/attention/self/key/MatMul:  96%|▉| 23/24 [00:47<00
# Compressing /encoder/layer.11/attention/self/key/MatMul: 100%|█| 24/24 [00:49<00
# Compressing /encoder/layer.11/attention/self/query/MatMul:   0%| | 0/24 [00:00<?
# Compressing /encoder/layer.10/output/dense/MatMul:  38%|▍| 36/96 [01:18<02:09,
# Compressing /encoder/layer.11/attention/self/query/MatMul:   4%| | 1/24 [00:02<0
# Compressing /encoder/layer.11/attention/self/query/MatMul:   8%| | 2/24 [00:04<0
# Compressing /encoder/layer.11/attention/self/query/MatMul:  12%|▏| 3/24 [00:06<0
# Compressing /encoder/layer.11/attention/self/query/MatMul:  17%|▏| 4/24 [00:09<0
# Compressing /encoder/layer.11/attention/self/query/MatMul:  21%|▏| 5/24 [00:11<0
# Compressing /encoder/layer.11/attention/self/query/MatMul:  25%|▎| 6/24 [00:13<0
# Compressing /encoder/layer.11/attention/self/query/MatMul:  29%|▎| 7/24 [00:15<0
# Compressing /encoder/layer.11/attention/self/query/MatMul:  33%|▎| 8/24 [00:17<0
# Compressing /encoder/layer.11/attention/self/query/MatMul:  38%|▍| 9/24 [00:19<0
# Compressing /encoder/layer.11/attention/self/query/MatMul:  42%|▍| 10/24 [00:21<
# Compressing /encoder/layer.11/attention/self/query/MatMul:  46%|▍| 11/24 [00:24<
# Compressing /encoder/layer.11/attention/self/query/MatMul:  50%|▌| 12/24 [00:26<
# Compressing /encoder/layer.10/output/dense/MatMul:  51%|▌| 49/96 [01:43<01:33,
# Compressing /encoder/layer.11/attention/self/query/MatMul:  54%|▌| 13/24 [00:28<
# Compressing /encoder/layer.11/attention/self/query/MatMul:  58%|▌| 14/24 [00:30<
# Compressing /encoder/layer.11/attention/self/query/MatMul:  67%|▋| 16/24 [00:34<
# Compressing /encoder/layer.11/attention/self/query/MatMul:  71%|▋| 17/24 [00:36<
# Compressing /encoder/layer.11/attention/self/query/MatMul:  75%|▊| 18/24 [00:38<
# Compressing /encoder/layer.11/attention/self/query/MatMul:  79%|▊| 19/24 [00:41<
# Compressing /encoder/layer.11/attention/self/query/MatMul:  83%|▊| 20/24 [00:43<
# Compressing /encoder/layer.11/attention/self/query/MatMul:  88%|▉| 21/24 [00:45<
# Compressing /encoder/layer.11/attention/self/query/MatMul:  96%|▉| 23/24 [00:49<
# Compressing /encoder/layer.11/attention/self/query/MatMul: 100%|█| 24/24 [00:51<
#
# Compressing /encoder/layer.11/attention/self/value/MatMul:   4%| | 1/24 [00:02<0
# Compressing /encoder/layer.11/attention/self/value/MatMul:   8%| | 2/24 [00:04<0
# Compressing /encoder/layer.11/attention/self/value/MatMul:  12%|▏| 3/24 [00:06<0
# Compressing /encoder/layer.11/attention/self/value/MatMul:  17%|▏| 4/24 [00:08<0
# Compressing /encoder/layer.11/attention/self/value/MatMul:  21%|▏| 5/24 [00:10<0
# Compressing /encoder/layer.11/attention/self/value/MatMul:  25%|▎| 6/24 [00:12<0
# Compressing /encoder/layer.11/attention/self/value/MatMul:  33%|▎| 8/24 [00:15<0
# Compressing /encoder/layer.11/attention/self/value/MatMul:  38%|▍| 9/24 [00:17<0
# Compressing /encoder/layer.10/output/dense/MatMul:  71%|▋| 68/96 [02:28<01:00,
# Compressing /encoder/layer.11/attention/self/value/MatMul:  46%|▍| 11/24 [00:22<
# Compressing /encoder/layer.11/attention/self/value/MatMul:  50%|▌| 12/24 [00:24<
# Compressing /encoder/layer.11/attention/self/value/MatMul:  54%|▌| 13/24 [00:26<
# Compressing /encoder/layer.11/attention/self/value/MatMul:  58%|▌| 14/24 [00:28<
# Compressing /encoder/layer.11/attention/self/value/MatMul:  62%|▋| 15/24 [00:30<
# Compressing /encoder/layer.11/attention/self/value/MatMul:  67%|▋| 16/24 [00:32<
# Compressing /encoder/layer.10/output/dense/MatMul:  78%|▊| 75/96 [02:42<00:42,
# Compressing /encoder/layer.11/attention/self/value/MatMul:  71%|▋| 17/24 [00:34<
# Compressing /encoder/layer.11/attention/self/value/MatMul:  79%|▊| 19/24 [00:38<
# Compressing /encoder/layer.11/attention/self/value/MatMul:  83%|▊| 20/24 [00:40<
# Compressing /encoder/layer.11/attention/self/value/MatMul:  88%|▉| 21/24 [00:42<
# Compressing /encoder/layer.11/attention/self/value/MatMul:  92%|▉| 22/24 [00:44<
# Compressing /encoder/layer.11/attention/self/value/MatMul:  96%|▉| 23/24 [00:46<
# Compressing /encoder/layer.11/attention/self/value/MatMul: 100%|█| 24/24 [00:48<
# Compressing /encoder/layer.11/attention/output/dense/MatMul:   0%| | 0/24 [00:00
# Compressing /encoder/layer.11/attention/output/dense/MatMul:   8%| | 2/24 [00:03
# Compressing /encoder/layer.11/attention/output/dense/MatMul:  12%|▏| 3/24 [00:05
# Compressing /encoder/layer.11/attention/output/dense/MatMul:  17%|▏| 4/24 [00:07
# Compressing /encoder/layer.10/output/dense/MatMul:  90%|▉| 86/96 [03:06<00:21,
# Compressing /encoder/layer.11/attention/output/dense/MatMul:  25%|▎| 6/24 [00:12
# Compressing /encoder/layer.11/attention/output/dense/MatMul:  29%|▎| 7/24 [00:14
# Compressing /encoder/layer.11/attention/output/dense/MatMul:  33%|▎| 8/24 [00:15
# Compressing /encoder/layer.11/attention/output/dense/MatMul:  38%|▍| 9/24 [00:18
# Compressing /encoder/layer.11/attention/output/dense/MatMul:  42%|▍| 10/24 [00:2
# Compressing /encoder/layer.11/attention/output/dense/MatMul:  46%|▍| 11/24 [00:2
# Compressing /encoder/layer.11/attention/output/dense/MatMul:  50%|▌| 12/24 [00:2
# Compressing /encoder/layer.11/attention/output/dense/MatMul:  54%|▌| 13/24 [00:2
# Compressing /encoder/layer.11/attention/output/dense/MatMul:  58%|▌| 14/24 [00:2
# Compressing /encoder/layer.10/output/dense/MatMul: 100%|█| 96/96 [03:28<00:00,
#
# Compressing /encoder/layer.11/attention/output/dense/MatMul:  67%|▋| 16/24 [00:3
# Compressing /encoder/layer.11/attention/output/dense/MatMul:  71%|▋| 17/24 [00:3
# Compressing /encoder/layer.11/attention/output/dense/MatMul:  75%|▊| 18/24 [00:3
# Compressing /encoder/layer.11/attention/output/dense/MatMul:  79%|▊| 19/24 [00:3
# Compressing /encoder/layer.11/attention/output/dense/MatMul:  83%|▊| 20/24 [00:3
# Compressing /encoder/layer.11/attention/output/dense/MatMul:  88%|▉| 21/24 [00:4
# Compressing /encoder/layer.11/attention/output/dense/MatMul:  92%|▉| 22/24 [00:4
# Compressing /encoder/layer.11/attention/output/dense/MatMul:  96%|▉| 23/24 [00:4
# Compressing /encoder/layer.11/attention/output/dense/MatMul: 100%|█| 24/24 [00:4
#
# Compressing /encoder/layer.11/intermediate/dense/MatMul:  38%|▍| 9/24 [00:18<00:
# Compressing /encoder/layer.11/intermediate/dense/MatMul:  42%|▍| 10/24 [00:19<00
# Compressing /encoder/layer.11/intermediate/dense/MatMul:  46%|▍| 11/24 [00:20<00
# Compressing /encoder/layer.11/intermediate/dense/MatMul:  50%|▌| 12/24 [00:21<00
# Compressing /encoder/layer.11/intermediate/dense/MatMul:  54%|▌| 13/24 [00:21<00
# Compressing /encoder/layer.11/intermediate/dense/MatMul:  58%|▌| 14/24 [00:22<00
# Compressing /encoder/layer.11/intermediate/dense/MatMul:  62%|▋| 15/24 [00:23<00
# Compressing /encoder/layer.11/intermediate/dense/MatMul:  67%|▋| 16/24 [00:23<00
# Compressing /encoder/layer.11/intermediate/dense/MatMul:  71%|▋| 17/24 [00:24<00
# Compressing /encoder/layer.11/intermediate/dense/MatMul:  75%|▊| 18/24 [00:25<00
# Compressing /encoder/layer.11/intermediate/dense/MatMul:  79%|▊| 19/24 [00:26<00
# Compressing /encoder/layer.11/intermediate/dense/MatMul:  83%|▊| 20/24 [00:26<00
# Compressing /encoder/layer.11/intermediate/dense/MatMul:  88%|▉| 21/24 [00:27<00
# Compressing /encoder/layer.11/intermediate/dense/MatMul:  92%|▉| 22/24 [00:28<00
# Compressing /encoder/layer.11/intermediate/dense/MatMul:  96%|▉| 23/24 [00:29<00
# Compressing /encoder/layer.11/intermediate/dense/MatMul: 100%|█| 24/24 [00:29<00
# INFO:sparsifyml.one_shot.sparsification.obcq.fast_obcq_modifier:Compressed model to effective overall sparsity of 0.014212667206187307. Full sparsity profile saved to experiments/20231114-091852/OBCQ/effective_sparsity_profile.json
# INFO:sparsifyml.one_shot.sparsification.obcq.fast_obcq_modifier:Running min/max calibration against dataset on 96 network activations
# INFO:sparsifyml.one_shot.sparsification.obcq.fast_obcq_modifier:Calibration complete
# INFO:sparsifyml.one_shot.sparsification.quantization.qdq:Injected Q/DQ blocks for 72 weights and 120 activations
# 2023-11-14 10:05:13 sparseml.exporters.transforms.onnx_transform INFO     [ConstantsToInitializers] Transformed 285 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[ConstantsToInitializers] Transformed 285 matches
# 2023-11-14 10:05:13 sparseml.exporters.transforms.onnx_transform INFO     [FoldIdentityInitializers] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[FoldIdentityInitializers] Transformed 0 matches
# 2023-11-14 10:05:13 sparseml.exporters.transforms.onnx_transform INFO     [InitializersToUint8] Transformed 168 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[InitializersToUint8] Transformed 168 matches
# 2023-11-14 10:05:14 sparseml.exporters.transforms.onnx_transform INFO     [FlattenQParams] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[FlattenQParams] Transformed 0 matches
# 2023-11-14 10:05:14 sparseml.exporters.transforms.onnx_transform INFO     [FoldConvDivBn] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[FoldConvDivBn] Transformed 0 matches
# 2023-11-14 10:05:15 sparseml.exporters.transforms.onnx_transform INFO     [DeleteRepeatedQdq] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[DeleteRepeatedQdq] Transformed 0 matches
# 2023-11-14 10:05:15 sparseml.exporters.transforms.onnx_transform INFO     [QuantizeQATEmbedding] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[QuantizeQATEmbedding] Transformed 0 matches
# 2023-11-14 10:05:15 sparseml.exporters.transforms.onnx_transform INFO     [PropagateEmbeddingQuantization] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[PropagateEmbeddingQuantization] Transformed 0 matches
# 2023-11-14 10:05:16 sparseml.exporters.transforms.onnx_transform INFO     [PropagateDequantThroughSplit] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[PropagateDequantThroughSplit] Transformed 0 matches
# 2023-11-14 10:05:17 sparseml.exporters.transforms.onnx_transform INFO     [MatMulAddToMatMulIntegerAddCastMul] Transformed 72 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[MatMulAddToMatMulIntegerAddCastMul] Transformed 72 matches
# 2023-11-14 10:05:18 sparseml.exporters.transforms.onnx_transform INFO     [MatMulToMatMulIntegerCastMul] Transformed 24 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[MatMulToMatMulIntegerCastMul] Transformed 24 matches
# 2023-11-14 10:05:18 sparseml.exporters.transforms.onnx_transform INFO     [FoldReLUQuants] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[FoldReLUQuants] Transformed 0 matches
# 2023-11-14 10:05:18 sparseml.exporters.transforms.onnx_transform INFO     [ConvToConvIntegerAddCastMul] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[ConvToConvIntegerAddCastMul] Transformed 0 matches
# 2023-11-14 10:05:18 sparseml.exporters.transforms.onnx_transform INFO     [GemmToQLinearMatMul] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[GemmToQLinearMatMul] Transformed 0 matches
# 2023-11-14 10:05:19 sparseml.exporters.transforms.onnx_transform INFO     [GemmToMatMulIntegerAddCastMul] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[GemmToMatMulIntegerAddCastMul] Transformed 0 matches
# 2023-11-14 10:05:19 sparseml.exporters.transforms.onnx_transform INFO     [QuantizeResiduals] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[QuantizeResiduals] Transformed 0 matches
# 2023-11-14 10:05:19 sparseml.exporters.transforms.onnx_transform INFO     [RemoveDuplicateQConvWeights] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[RemoveDuplicateQConvWeights] Transformed 0 matches
# 2023-11-14 10:05:20 sparseml.exporters.transforms.onnx_transform INFO     [RemoveDuplicateQuantizeOps] Transformed 0 matches
# INFO:sparseml.exporters.transforms.onnx_transform:[RemoveDuplicateQuantizeOps] Transformed 0 matches
# INFO:sparsify.run one_shot: Model saved to deployment directory: /home/zeroshot/nm/examples/notebooks/sparsify-bge-small/deployment

# %%
# !mv deployment bge-small-en-v1.5-quant
# !cp bge-small-en-v1.5-dense/tokenizer.json bge-small-en-v1.5-quant/
# !cp bge-small-en-v1.5-dense/config.json bge-small-en-v1.5-quant/
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %% [markdown]
# # Testing the DeepSparseSentenceTransformers Embeddings Pipeline

# %%
from deepsparse.sentence_transformers import DeepSparseSentenceTransformer

quant = "bge-small-en-v1.5-quant"
sample_text = "I love quantized embedding models!"

quant_pipe = DeepSparseSentenceTransformer(quant, export=False)
quant_infer = quant_pipe.encode(sample_text)

# Get Shapes
print(quant_infer.shape)
# Out:
# 2023-11-14 10:07:38 deepsparse.engine WARNING  batch_size < 1 so disabling batch size override
# [nm_ort 7f340d094000 >WARN<  is_supported_graph src/onnxruntime_neuralmagic/supported/ops.cc:150] Warning: Optimized runtime disabled - Detected dynamic input input_ids dim 0. Set inputs to static shapes to enable optimal performance.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# (384,)

# %% [markdown]
# # Evaluate the Accuracy of the Dense vs. Quantized BGE Models on the STSB Dataset
#
# The [DeepSparseSentenceTransformer](https://github.com/neuralmagic/deepsparse/tree/main/src/deepsparse/sentence_transformers) integration allows easy access for compressed models to be evaluated on the [MTEB Leaderboard](https://huggingface.co/spaces/mteb/leaderboard). Let's compare the performance of the dense vs. quantized models on the STSB validation split:

# %%
# !pip install mteb -q
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
from mteb import MTEB

# Specify the model to use
quant = "bge-small-en-v1.5-quant"
dense = "BAAI/bge-small-en-v1.5"

# DeepSparse Model Evaluation
from deepsparse.sentence_transformers import DeepSparseSentenceTransformer
model = DeepSparseSentenceTransformer(quant, export=False)
evaluation = MTEB(tasks=["STSBenchmark"])
results_ds = evaluation.run(model, output_folder=f"results/ds-{quant}")
print(results_ds)

# Original SentenceTransformers Model Evaluation
import sentence_transformers
model = sentence_transformers.SentenceTransformer(dense)
evaluation = MTEB(tasks=["STSBenchmark"])
results_st = evaluation.run(model, output_folder=f"results/st-{dense}")
print(results_st)
# Out:
# 2023-11-14 10:10:46 deepsparse.engine WARNING  batch_size < 1 so disabling batch size override
# [nm_ort 7f340d094000 >WARN<  is_supported_graph src/onnxruntime_neuralmagic/supported/ops.cc:150] Warning: Optimized runtime disabled - Detected dynamic input input_ids dim 0. Set inputs to static shapes to enable optimal performance.
# ───────────────────────────────────────────────── Selected tasks  ─────────────────────────────────────────────────
# STS
#     - STSBenchmark, s2s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# Batches:   0%|          | 0/24 [00:00<?, ?it/s]
# Batches:   0%|          | 0/24 [00:00<?, ?it/s]
# Batches:   0%|          | 0/22 [00:00<?, ?it/s]
# Batches:   0%|          | 0/22 [00:00<?, ?it/s]
# {'STSBenchmark': {'mteb_version': '1.1.1', 'dataset_revision': 'b0fddb56ed78048fa8b90373c8a3cfc37b684831', 'mteb_dataset_name': 'STSBenchmark', 'validation': {'cos_sim': {'pearson': 0.8794062860922744, 'spearman': 0.8844550053896325}, 'manhattan': {'pearson': 0.8878536584253526, 'spearman': 0.8895857544820187}, 'euclidean': {'pearson': 0.887834459531111, 'spearman': 0.8895413237473978}, 'evaluation_time': 14.8}, 'test': {'cos_sim': {'pearson': 0.8473532103761534, 'spearman': 0.8583765105094451}, 'manhattan': {'pearson': 0.8608693121882481, 'spearman': 0.8616294524581138}, 'euclidean': {'pearson': 0.8628642729555878, 'spearman': 0.8631236609576122}, 'evaluation_time': 11.84}}}
# ───────────────────────────────────────────────── Selected tasks  ─────────────────────────────────────────────────
# STS
#     - STSBenchmark, s2s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# {'STSBenchmark': {'mteb_version': '1.1.1', 'dataset_revision': 'b0fddb56ed78048fa8b90373c8a3cfc37b684831', 'mteb_dataset_name': 'STSBenchmark', 'validation': {'cos_sim': {'pearson': 0.8828211766495108, 'spearman': 0.8892465763120051}, 'manhattan': {'pearson': 0.886201824808084, 'spearman': 0.8907627276162985}, 'euclidean': {'pearson': 0.8868149931196716, 'spearman': 0.8913096186609996}, 'evaluation_time': 4.43}, 'test': {'cos_sim': {'pearson': 0.8431285123201885, 'spearman': 0.8586295017067542}, 'manhattan': {'pearson': 0.854393933014824, 'spearman': 0.8591549232752812}, 'euclidean': {'pearson': 0.8565471782504085, 'spearman': 0.8612847755343875}, 'evaluation_time': 1.19}}}

# %% [markdown]
# The quantized model achieves 99.9% recovery when compared to the dense model on MTEB's `cos_sim` `spearman` metric.

# %% [markdown]
# # Benchmark the Dense PyTorch vs. Quantized ONNX Model for Latency
#
# In addition to the MTEB benchmarking, the integration includes a custom script for benchmarking latency and throughput, let's test how the dense vs. quantized model perform against each other. First, git clone deepsparse:

# %%
# !git clone https://github.com/neuralmagic/deepsparse.git
# Out:
# Cloning into 'deepsparse'...
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# remote: Enumerating objects: 18974, done.
# remote: Counting objects: 100% (5600/5600), done.
# remote: Compressing objects: 100% (1547/1547), done.
# remote: Total 18974 (delta 4935), reused 4451 (delta 4037), pack-reused 13374
# Receiving objects: 100% (18974/18974), 139.80 MiB | 31.52 MiB/s, done.
# Resolving deltas: 100% (13356/13356), done.

# %% [markdown]
# Now, run this CLI command to benchmmark the models' latency on encoding 100 sentences on a max sequence length=512 and batch size=1:

# %%
# !python deepsparse/src/deepsparse/sentence_transformers/benchmark_encoding.py --base_model BAAI/bge-small-en-v1.5 --sparse_model bge-small-en-v1.5-quant
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2023-11-14 10:13:18 deepsparse.engine WARNING  batch_size < 1 so disabling batch size override
# DeepSparse, Copyright 2021-present / Neuralmagic, Inc. version: 1.6.0.20231110 COMMUNITY | (6c521a73) (release) (optimized) (system=avx2_vnni, binary=avx2)
# [nm_ort 7f4e9f8be000 >WARN<  is_supported_graph src/onnxruntime_neuralmagic/supported/ops.cc:150] Warning: Optimized runtime disabled - Detected dynamic input input_ids dim 0. Set inputs to static shapes to enable optimal performance.
#
# [SentenceTransformer]
# Batch size: 1, Sentence length: 700
# Latency: 100 sentences in 23.41 seconds
# Throughput: 4.27 sentences/second
# Batches: 100%|████████████████████████████████| 100/100 [00:07<00:00, 14.13it/s]
#
# [DeepSparse Optimized]
# Batch size: 1, Sentence length: 700
# Latency: 100 sentences in 7.09 seconds
# Throughput: 14.11 sentences/second

# %% [markdown]
# The quantized BGE model is able to improve latency performance against the dense variant on a 10 core laptop by 3.3X! Furthermore, on optimized hardware, especially avx512 with VNNI instructions, up to 5X improvement can be observed.
